# %%
#importing libraries
import os
import pandas as pd
import asyncio
import json
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright

# Function to load progress from a file
def load_progress():
    if os.path.exists("progress.json"):
        with open("progress.json", "r") as file:
            return json.load(file)
    else:
        return {"current_batch": None, "links": []}

# Function to save progress to a file
def save_progress(current_batch, links):
    progress = {"current_batch": current_batch, "links": links}
    with open("progress.json", "w") as file:
        json.dump(progress, file)

# Function to save company data to a file
def save_company_data(company_data):
    file_path = os.path.join(os.getcwd(), "company_data.json")
    with open(file_path, "w") as file:
        json.dump(company_data, file, indent=4)
    print(f"Company data has been saved to '{file_path}'.")

# Function to save company data progress to a file
def save_company_progress(company_data):
    progress_path = os.path.join(os.getcwd(), "company_data_progress.json")
    with open(progress_path, "w") as file:
        json.dump(company_data, file, indent=4)
    print(f"Company data progress has been saved to '{progress_path}'.")

# Function to load company data progress from a file
def load_company_progress():
    if os.path.exists("company_data_progress.json"):
        with open("company_data_progress.json", "r") as file:
            return json.load(file)
    else:
        return []

# Function to scrape all batch numbers
async def scrape_all_batch_numbers():
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        await page.goto("https://www.ycombinator.com/companies")
        
        # Wait for the main content to load
        await page.wait_for_selector('div._facet_99gj3_85')
        
        # Click on the "More options" link to load additional content
        await page.click('a._showMoreLess_99gj3_241')
        
        # Wait for additional content to load
        await page.wait_for_selector('div._facet_99gj3_85')
        
        # Get the HTML content after all content is loaded
        html_content = await page.content()

    soup = BeautifulSoup(html_content, "html.parser")
    batch_elements = soup.select('div._facet_99gj3_85:has(h4:-soup-contains("Batch")) div:has(label)')

    batch_numbers = []
    for batch in batch_elements:
        span = batch.find('span', class_='_label_99gj3_225')  # Find the span element
        if span:  # Check if span element exists
            batch_numbers.append(span.text)
    
    return batch_numbers
    
#function to scrape company links
async def scrape_company_links(batch_num):
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        await page.goto(f"https://www.ycombinator.com/companies?batch={batch_num}")
        await page.wait_for_selector('a._company_99gj3_339')
        # Scroll down the page until there are no more new companies
        last_height = await page.evaluate("document.body.scrollHeight")
        while True:
            try:
                await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
                await page.wait_for_timeout(6000)  # Let the page load
                new_height = await page.evaluate("document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                print("Saving links scraped so far and retrying...")
                break
        
        html_content = await page.content()

    soup = BeautifulSoup(html_content, "html.parser")
    company_cards = soup.find_all("a", class_="_company_99gj3_339")

    companies_links = []
    for card in company_cards:
        company_url = f"https://www.ycombinator.com{card['href']}"
        companies_links.append(company_url)

    return companies_links
    
#function to scrape detailed company information
async def scrape_company_info(company_url):
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()

        # Retry logic
        for attempt in range(3):  # Retry up to 3 times
            try:
                await page.goto(company_url, timeout=30000)  # Set timeout to 30 seconds
                break  # Break the loop if successful
            except Exception as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt < 2:
                    print("Retrying...")
                else:
                    print("Maximum attempts reached. Skipping this URL.")
                    return None  # Return None if maximum attempts reached
        
        if page.url != company_url:
            print("Page navigation failed. Skipping this URL.")
            return None

        # Wait for the main content to load
        await page.wait_for_selector('h1.font-extralight')

        # Get the HTML content after all content is loaded
        html_content = await page.content()

    soup = BeautifulSoup(html_content, "html.parser")
    
    # Extract company information
    company_info = {}
    company_info['Name'] = soup.select_one('h1.font-extralight').text.strip()
    company_info['Tagline'] = soup.find('h3').get_text()
    company_info['Description'] = soup.select_one('p.whitespace-pre-line').text.strip()
    company_info['Batch'] = soup.select_one('div.flex.flex-row.items-center.gap-\[6px\] span').text.strip()
    company_info['Company Type'] = soup.select_one('div.flex.flex-row.items-center.justify-between').text.strip()
    company_info['Industry Tags'] = [tag.text.strip() for tag in soup.select('a div.yc-tw-Pill.rounded-sm.bg-\[#E6E4DC\].uppercase.tracking-widest.px-3py-\[3px\].text-\[12px\].font-thin')] if soup.select('a div.yc-tw-Pill.rounded-sm.bg-\[#E6E4DC\].uppercase.tracking-widest.px-3py-\[3px\].text-\[12px\].font-thin') else None
    company_info['Location'] = soup.select_one('div.flex.flex-row.justify-between:contains("Location")').text.strip()
    company_info['Website URL'] = soup.select_one('a[href].mb-2.whitespace-nowrap')['href']
    company_info['Year Founded'] = soup.select_one('div.flex.flex-row.justify-between:contains("Founded")').text.strip()
    company_info['Team Size'] = soup.select_one('div.flex.flex-row.justify-between:contains("Team Size")').text.strip()
    
    # Extract social media links
    social_links = soup.select('div.space-x-2 a')
    for link in social_links:
        if 'linkedin.com' in link['href']:
            company_info['LinkedIn Profile'] = link['href']
        elif 'twitter.com' in link['href']:
            company_info['Twitter Handle'] = link['href']
        elif 'facebook.com' in link['href']:
            company_info['Facebook Page'] = link['href']
    
    # Extract founder information
    founders = []
    founder_elements = soup.select('div.flex.flex-row.flex-col.items-start.gap-3.md\:flex-row')

    for founder_element in founder_elements:
        founder = {}
        founder_name_element = founder_element.select_one('div.flex-grow h3.text-lg.font-bold')
        if founder_name_element:
            founder['Name'] = founder_name_element.text.strip()
        
        # Extracting Role
        role_element = founder_element.select_one('div.flex-grow h3.text-lg.font-bold')
        if role_element:
            founder['Role'] = role_element.get_text().split(',')[1].strip() if (role_element and ',' in role_element.get_text()) else None
        
        # Extracting Biography
        biography_element = founder_element.select_one('div.flex-grow p')
        if biography_element:
            founder['Biography'] = biography_element.text.strip()
        
        # Extracting Links
        links = founder_element.select('a')
        for link in links:
            href = link.get('href')
            if href:
                if 'linkedin.com' in href:
                    founder['LinkedIn Profile'] = href
                elif 'twitter.com' in href:
                    founder['Twitter Profile'] = href

        founders.append(founder)

    company_info['Founders'] = founders

    return company_info

async def main():
    # Load progress
    progress = load_progress()
    current_batch = progress["current_batch"]
    links = progress["links"]

    if current_batch is None:
        # Start from the beginning if no progress is saved
        batch_numbers = await scrape_all_batch_numbers()
        current_batch_index = 0
    else:
        # Continue from the last batch if progress is saved
        batch_numbers = await scrape_all_batch_numbers()
        current_batch_index = batch_numbers.index(current_batch) + 1  # Start from the next batch

    total_companies = 0
    for batch_num in batch_numbers[current_batch_index:]:
        print(f"Scraping batch {batch_num}...")
        batch_links = await scrape_company_links(batch_num)
        links.extend(batch_links)
        save_progress(batch_num, links)
        
        total_companies += len(batch_links)
        if total_companies >= 4665:
            print("Total 4665 companies' information has been scraped.")
            break

    # Resume scraping company information
    company_data_progress = load_company_progress()  # Load company data progress
    company_data = []  # List to store scraped company information

    for link in links:
        if link not in company_data_progress:  # Check if company information already scraped
            print(f"Scraping company information from {link}...")
            try:
                company_info = await scrape_company_info(link)
                company_data.append(company_info)
                company_data_progress.append(link)  # Add link to progress
                if len(company_data) >= 4665:
                    print("Total 4665 companies' information has been scraped.")
                    break
            except Exception as e:
                print(f"An error occurred while scraping {link}: {str(e)}")
                print("Saving scraped data so far and retrying...")
                break

    # Save company data to JSON file
    save_company_data(company_data)

    # Save company data progress to JSON file
    save_company_progress(company_data_progress)

# Run the main function
await main()
# Out:
# Scraping company information from https://www.ycombinator.com/companies/bitsample...
# An error occurred while scraping https://www.ycombinator.com/companies/bitsample: 'NoneType' object is not subscriptable
# Saving scraped data so far and retrying...
# Company data has been saved to 'C:\Users\user\company_data.json'.
# Company data progress has been saved to 'C:\Users\user\company_data_progress.json'.

# %% [markdown]
# ## Adding company urls to company_data.json file

# %%
import json
import re

# Load company data from company_data.json
with open("company_data.json", "r") as json_file:
    company_data = json.load(json_file)

# Load company URLs from company_data_progress.json
with open("progress.json", "r") as urls_file:
    progress_data = json.load(urls_file)
# Extracting URLs from the second dictionary
url_list = []
links_data = progress_data.get('links', [])
if isinstance(links_data, list):
    url_list = links_data

# Create a dictionary to map company names to URLs
company_url_map = {url.split("/")[-1]: url for url in url_list}
# List to store companies for which URLs are not updated
company_not_updated=[]

# Function to remove words in parentheses from a string

def remove_words_in_parentheses(text):
    return re.sub(r'\([^)]*\)', '', text)
# Iterate through the company data
for idx, company in enumerate(company_data):
    # Check if company is not None
    if company is not None:
        # Get the name of the company
        company_name =remove_words_in_parentheses(company.get("Name").lower().replace(" ", "-").replace(".","-").replace("&","and"))
        
        # Print company name and index for debugging
        print(f"Processing company {company_name} at index {idx}")
        
        # Check if the company name exists and is not None
        if company_name:
           
            # Check if the company name exists in the URL map
            if company_name in company_url_map:
                # Add URL to the company's dictionary
                
                company["url"] = company_url_map[company_name]
                print(company["url"])
            else:
                company_not_updated.append(company_name)
# Save updated company data to company_data
with open("company_data.json", "w") as json_file:
        json.dump(company_data, json_file, indent=4)
print("Company data successfully updated.")
print(len(company_not_updated))
#print(f"the company which is not updated with url :{company_not_updated}")
# Out:
# Processing company trueclaim at index 0
# https://www.ycombinator.com/companies/trueclaim
# Processing company cocrafter at index 1
# https://www.ycombinator.com/companies/cocrafter
# Processing company reform at index 2
# https://www.ycombinator.com/companies/reform
# Processing company piramidal at index 3
# https://www.ycombinator.com/companies/piramidal
# Processing company junction-bioscience at index 4
# https://www.ycombinator.com/companies/junction-bioscience
# Processing company oddsview at index 5
# https://www.ycombinator.com/companies/oddsview
# Processing company silogy at index 6
# https://www.ycombinator.com/companies/silogy
# Processing company senso at index 7
# https://www.ycombinator.com/companies/senso
# Processing company eris-biotech at index 8
# https://www.ycombinator.com/companies/eris-biotech
# Processing company powder at index 9
# https://www.ycombinator.com/companies/powder
# Processing company openfoundry at index 10
# https://www.ycombinator.com/companies/openfoundry
# Processing company goldenbasis at index 11
# https://www.ycombinator.com/companies/goldenbasis
# Processing company arcane at index 12
# https://www.ycombinator.com/companies/arcane
# Processing company somn at index 13
# https://www.ycombinator.com/companies/somn
# Processing company magic-hour at index 14
# https://www.ycombinator.com/companies/magic-hour
# Processing company ryse at index 15
# https://www.ycombinator.com/companies/ryse
# Processing company lumona at index 16
# https://www.ycombinator.com/companies/lumona
# Processing company datacurve at index 17
# https://www.ycombinator.com/companies/datacurve
# Processing company marblism at index 18
# https://www.ycombinator.com/companies/marblism
# Processing company commodityai at index 19
# https://www.ycombinator.com/companies/commodityai
# Processing company veles at index 20
# https://www.ycombinator.com/companies/veles
# Processing company miden at index 21
# https://www.ycombinator.com/companies/miden
# Processing company fluently at index 22
# https://www.ycombinator.com/companies/fluently
# Processing company basepilot at index 23
# https://www.ycombinator.com/companies/basepilot
# Processing company aqua-voice at index 24
# https://www.ycombinator.com/companies/aqua-voice
# Processing company onedoc at index 25
# https://www.ycombinator.com/companies/onedoc
# Processing company xpay at index 26
# https://www.ycombinator.com/companies/xpay
# Processing company deepnight at index 27
# https://www.ycombinator.com/companies/deepnight
# Processing company vista-space at index 28
# https://www.ycombinator.com/companies/vista-space
# Processing company corefin at index 29
# https://www.ycombinator.com/companies/corefin
# Processing company ocular-ai at index 30
# https://www.ycombinator.com/companies/ocular-ai
# Processing company retell-ai at index 31
# https://www.ycombinator.com/companies/retell-ai
# Processing company rove at index 32
# https://www.ycombinator.com/companies/rove
# Processing company camelqa at index 33
# https://www.ycombinator.com/companies/camelqa
# Processing company spark at index 34
# https://www.ycombinator.com/companies/spark
# Processing company titan at index 35
# https://www.ycombinator.com/companies/titan
# Processing company terrakotta at index 36
# https://www.ycombinator.com/companies/terrakotta
# Processing company stacksync at index 37
# https://www.ycombinator.com/companies/stacksync
# Processing company hatchet at index 38
# Processing company shepherd at index 39
# https://www.ycombinator.com/companies/shepherd
# Processing company sonauto at index 40
# https://www.ycombinator.com/companies/sonauto
# Processing company bitesight at index 41
# https://www.ycombinator.com/companies/bitesight
# Processing company velorum-therapeutics at index 42
# https://www.ycombinator.com/companies/velorum-therapeutics
# Processing company zep-ai at index 43
# https://www.ycombinator.com/companies/zep-ai
# Processing company openmart at index 44
# https://www.ycombinator.com/companies/openmart
# Processing company triply at index 45
# https://www.ycombinator.com/companies/triply
# Processing company amber-ai at index 46
# https://www.ycombinator.com/companies/amber-ai
# Processing company thorntale at index 47
# https://www.ycombinator.com/companies/thorntale
# Processing company alai at index 48
# https://www.ycombinator.com/companies/alai
# Processing company pocketpod at index 49
# https://www.ycombinator.com/companies/pocketpod
# Processing company brainbase at index 50
# https://www.ycombinator.com/companies/brainbase
# Processing company focal at index 51
# https://www.ycombinator.com/companies/focal
# Processing company givefront at index 52
# https://www.ycombinator.com/companies/givefront
# Processing company cleva at index 53
# https://www.ycombinator.com/companies/cleva
# Processing company oma-care at index 54
# https://www.ycombinator.com/companies/oma-care
# Processing company artos at index 55
# https://www.ycombinator.com/companies/artos
# Processing company model-ml at index 56
# https://www.ycombinator.com/companies/model-ml
# Processing company betterbasket at index 57
# https://www.ycombinator.com/companies/betterbasket
# Processing company circleback at index 58
# https://www.ycombinator.com/companies/circleback
# Processing company just-words at index 59
# https://www.ycombinator.com/companies/just-words
# Processing company risotto at index 60
# https://www.ycombinator.com/companies/risotto
# Processing company dianahr at index 61
# https://www.ycombinator.com/companies/dianahr
# Processing company heartbyte at index 62
# https://www.ycombinator.com/companies/heartbyte
# Processing company yondu at index 63
# https://www.ycombinator.com/companies/yondu
# Processing company dawn at index 64
# https://www.ycombinator.com/companies/dawn
# Processing company lumina at index 65
# https://www.ycombinator.com/companies/lumina
# Processing company centauri-ai at index 66
# https://www.ycombinator.com/companies/centauri-ai
# Processing company prosights at index 67
# https://www.ycombinator.com/companies/prosights
# Processing company manifold-freight at index 68
# https://www.ycombinator.com/companies/manifold-freight
# Processing company edgetrace at index 69
# https://www.ycombinator.com/companies/edgetrace
# Processing company clarum at index 70
# https://www.ycombinator.com/companies/clarum
# Processing company opencall-ai at index 71
# https://www.ycombinator.com/companies/opencall-ai
# Processing company voicepanel at index 72
# https://www.ycombinator.com/companies/voicepanel
# Processing company skygaze at index 73
# https://www.ycombinator.com/companies/skygaze
# Processing company abel at index 74
# https://www.ycombinator.com/companies/abel
# Processing company offdeal at index 75
# https://www.ycombinator.com/companies/offdeal
# Processing company delve at index 76
# https://www.ycombinator.com/companies/delve
# Processing company andy-ai at index 77
# https://www.ycombinator.com/companies/andy-ai
# Processing company hazel at index 78
# Processing company shiboleth at index 79
# https://www.ycombinator.com/companies/shiboleth
# Processing company kontractify at index 80
# https://www.ycombinator.com/companies/kontractify
# Processing company soundry-ai at index 81
# https://www.ycombinator.com/companies/soundry-ai
# Processing company elodin at index 82
# https://www.ycombinator.com/companies/elodin
# Processing company hostai at index 83
# https://www.ycombinator.com/companies/hostai
# Processing company trieve at index 84
# https://www.ycombinator.com/companies/trieve
# Processing company tensorfuse at index 85
# https://www.ycombinator.com/companies/tensorfuse
# Processing company toma at index 86
# https://www.ycombinator.com/companies/toma
# Processing company carma at index 87
# https://www.ycombinator.com/companies/carma
# Processing company preloop at index 88
# https://www.ycombinator.com/companies/preloop
# Processing company superagent at index 89
# https://www.ycombinator.com/companies/superagent
# Processing company bilanc at index 90
# https://www.ycombinator.com/companies/bilanc
# Processing company sevnai at index 91
# https://www.ycombinator.com/companies/sevnai
# Processing company browser-buddy at index 92
# https://www.ycombinator.com/companies/browser-buddy
# Processing company astro-mechanica at index 93
# https://www.ycombinator.com/companies/astro-mechanica
# Processing company codeant-ai at index 94
# https://www.ycombinator.com/companies/codeant-ai
# Processing company draftaid at index 95
# https://www.ycombinator.com/companies/draftaid
# Processing company metofico at index 96
# https://www.ycombinator.com/companies/metofico
# Processing company ellipsis at index 97
# https://www.ycombinator.com/companies/ellipsis
# Processing company dime at index 98
# https://www.ycombinator.com/companies/dime
# Processing company sparechange at index 99
# https://www.ycombinator.com/companies/sparechange
# Processing company pythagora- at index 100
# Processing company wuri at index 101
# https://www.ycombinator.com/companies/wuri
# Processing company open at index 102
# https://www.ycombinator.com/companies/open
# Processing company aedilic at index 103
# https://www.ycombinator.com/companies/aedilic
# Processing company salvy at index 104
# https://www.ycombinator.com/companies/salvy
# Processing company centralize at index 105
# https://www.ycombinator.com/companies/centralize
# Processing company phospho at index 106
# https://www.ycombinator.com/companies/phospho
# Processing company quantic at index 107
# https://www.ycombinator.com/companies/quantic
# Processing company resonance at index 108
# https://www.ycombinator.com/companies/resonance
# Processing company firebender at index 109
# https://www.ycombinator.com/companies/firebender
# Processing company aether-energy at index 110
# https://www.ycombinator.com/companies/aether-energy
# Processing company kiosk at index 111
# https://www.ycombinator.com/companies/kiosk
# Processing company ragas at index 112
# https://www.ycombinator.com/companies/ragas
# Processing company sync-labs at index 113
# https://www.ycombinator.com/companies/sync-labs
# Processing company pandasai at index 114
# https://www.ycombinator.com/companies/pandasai
# Processing company inquery at index 116
# Processing company markprompt at index 117
# https://www.ycombinator.com/companies/markprompt
# Processing company tamarind-bio at index 118
# https://www.ycombinator.com/companies/tamarind-bio
# Processing company anaphero at index 119
# https://www.ycombinator.com/companies/anaphero
# Processing company swift at index 120
# Processing company intercept at index 121
# https://www.ycombinator.com/companies/intercept
# Processing company creo at index 122
# https://www.ycombinator.com/companies/creo
# Processing company decipher-ai at index 123
# https://www.ycombinator.com/companies/decipher-ai
# Processing company infinity-ai at index 124
# https://www.ycombinator.com/companies/infinity-ai
# Processing company double at index 125
# Processing company speck at index 126
# https://www.ycombinator.com/companies/speck
# Processing company guide-labs at index 127
# https://www.ycombinator.com/companies/guide-labs
# Processing company omniai at index 128
# https://www.ycombinator.com/companies/omniai
# Processing company keywords-ai at index 129
# https://www.ycombinator.com/companies/keywords-ai
# Processing company promptarmor at index 130
# https://www.ycombinator.com/companies/promptarmor
# Processing company zaymo at index 131
# https://www.ycombinator.com/companies/zaymo
# Processing company glimmer at index 132
# https://www.ycombinator.com/companies/glimmer
# Processing company celest at index 133
# https://www.ycombinator.com/companies/celest
# Processing company cloudcruise at index 135
# https://www.ycombinator.com/companies/cloudcruise
# Processing company attunement at index 136
# https://www.ycombinator.com/companies/attunement
# Processing company lucite at index 137
# https://www.ycombinator.com/companies/lucite
# Processing company selera-medical at index 138
# https://www.ycombinator.com/companies/selera-medical
# Processing company onegrep at index 139
# https://www.ycombinator.com/companies/onegrep
# Processing company parasale at index 140
# https://www.ycombinator.com/companies/parasale
# Processing company tusk at index 141
# https://www.ycombinator.com/companies/tusk
# Processing company partnerhq at index 142
# https://www.ycombinator.com/companies/partnerhq
# Processing company atopile at index 143
# https://www.ycombinator.com/companies/atopile
# Processing company blume-benefits at index 144
# https://www.ycombinator.com/companies/blume-benefits
# Processing company airfront at index 145
# https://www.ycombinator.com/companies/airfront
# Processing company synsorybio at index 146
# https://www.ycombinator.com/companies/synsorybio
# Processing company yoneda-labs at index 147
# https://www.ycombinator.com/companies/yoneda-labs
# Processing company tokenowl at index 148
# https://www.ycombinator.com/companies/tokenowl
# Processing company hona at index 149
# https://www.ycombinator.com/companies/hona
# Processing company topo at index 150
# https://www.ycombinator.com/companies/topo
# Processing company trellis at index 151
# https://www.ycombinator.com/companies/trellis
# Processing company ecliptor at index 152
# https://www.ycombinator.com/companies/ecliptor
# Processing company greenboard at index 153
# https://www.ycombinator.com/companies/greenboard
# Processing company eggnog at index 154
# https://www.ycombinator.com/companies/eggnog
# Processing company artisan-ai at index 155
# https://www.ycombinator.com/companies/artisan-ai
# Processing company octolane-ai at index 156
# https://www.ycombinator.com/companies/octolane-ai
# Processing company suretynow at index 157
# https://www.ycombinator.com/companies/suretynow
# Processing company roe-ai at index 158
# https://www.ycombinator.com/companies/roe-ai
# Processing company arini at index 159
# https://www.ycombinator.com/companies/arini
# Processing company paradigm at index 160
# https://www.ycombinator.com/companies/paradigm
# Processing company pointone at index 161
# https://www.ycombinator.com/companies/pointone
# Processing company patchwork at index 162
# https://www.ycombinator.com/companies/patchwork
# Processing company starlight-charging at index 163
# https://www.ycombinator.com/companies/starlight-charging
# Processing company assembly at index 164
# https://www.ycombinator.com/companies/assembly
# Processing company mathdash at index 165
# https://www.ycombinator.com/companies/mathdash
# Processing company leaping at index 166
# https://www.ycombinator.com/companies/leaping
# Processing company basalt-tech at index 167
# https://www.ycombinator.com/companies/basalt-tech
# Processing company carousel-technologies at index 168
# https://www.ycombinator.com/companies/carousel-technologies
# Processing company agentic-labs at index 169
# Processing company dalmatian at index 170
# https://www.ycombinator.com/companies/dalmatian
# Processing company pivot-robots at index 171
# https://www.ycombinator.com/companies/pivot-robots
# Processing company aidy at index 172
# https://www.ycombinator.com/companies/aidy
# Processing company dgi-apparel at index 173
# https://www.ycombinator.com/companies/dgi-apparel
# Processing company buster at index 174
# https://www.ycombinator.com/companies/buster
# Processing company garage at index 175
# https://www.ycombinator.com/companies/garage
# Processing company mango-health at index 176
# https://www.ycombinator.com/companies/mango-health
# Processing company argon-ai,-inc- at index 177
# Processing company ncompass-technologies at index 178
# https://www.ycombinator.com/companies/ncompass-technologies
# Processing company pretzel-ai at index 179
# https://www.ycombinator.com/companies/pretzel-ai
# Processing company apriora at index 180
# https://www.ycombinator.com/companies/apriora
# Processing company malibou at index 181
# https://www.ycombinator.com/companies/malibou
# Processing company quary at index 182
# https://www.ycombinator.com/companies/quary
# Processing company hemingway at index 183
# https://www.ycombinator.com/companies/hemingway
# Processing company tile at index 184
# https://www.ycombinator.com/companies/tile
# Processing company adagy-robotics at index 185
# https://www.ycombinator.com/companies/adagy-robotics
# Processing company momentic at index 186
# https://www.ycombinator.com/companies/momentic
# Processing company reducto at index 187
# https://www.ycombinator.com/companies/reducto
# Processing company vectorview at index 188
# https://www.ycombinator.com/companies/vectorview
# Processing company maia at index 189
# https://www.ycombinator.com/companies/maia
# Processing company nuanced,-inc- at index 190
# Processing company precip at index 191
# https://www.ycombinator.com/companies/precip
# Processing company tracecat at index 192
# https://www.ycombinator.com/companies/tracecat
# Processing company kabilah at index 193
# https://www.ycombinator.com/companies/kabilah
# Processing company sonia at index 194
# https://www.ycombinator.com/companies/sonia
# Processing company maihem at index 195
# https://www.ycombinator.com/companies/maihem
# Processing company ion-design at index 196
# https://www.ycombinator.com/companies/ion-design
# Processing company duckie at index 197
# https://www.ycombinator.com/companies/duckie
# Processing company happenstance at index 198
# https://www.ycombinator.com/companies/happenstance
# Processing company ubicloud at index 199
# https://www.ycombinator.com/companies/ubicloud
# Processing company greptile at index 200
# https://www.ycombinator.com/companies/greptile
# Processing company heypurple at index 201
# https://www.ycombinator.com/companies/heypurple
# Processing company ego at index 202
# https://www.ycombinator.com/companies/ego
# Processing company leya at index 203
# https://www.ycombinator.com/companies/leya
# Processing company scritch at index 204
# https://www.ycombinator.com/companies/scritch
# Processing company radmate-ai at index 205
# https://www.ycombinator.com/companies/radmate-ai
# Processing company ssoready at index 206
# https://www.ycombinator.com/companies/ssoready
# Processing company relari at index 207
# https://www.ycombinator.com/companies/relari
# Processing company drymerge at index 208
# https://www.ycombinator.com/companies/drymerge
# Processing company navier-ai at index 209
# https://www.ycombinator.com/companies/navier-ai
# Processing company upsolve-ai at index 210
# https://www.ycombinator.com/companies/upsolve-ai
# Processing company sciphi at index 211
# https://www.ycombinator.com/companies/sciphi
# Processing company agenthub at index 212
# https://www.ycombinator.com/companies/agenthub
# Processing company driver-ai at index 213
# https://www.ycombinator.com/companies/driver-ai
# Processing company lantern at index 214
# https://www.ycombinator.com/companies/lantern
# Processing company danswer at index 215
# https://www.ycombinator.com/companies/danswer
# Processing company yenmo at index 216
# https://www.ycombinator.com/companies/yenmo
# Processing company governgpt at index 217
# https://www.ycombinator.com/companies/governgpt
# Processing company stitch-technologies at index 218
# https://www.ycombinator.com/companies/stitch-technologies
# Processing company openpipe at index 219
# https://www.ycombinator.com/companies/openpipe
# Processing company flex at index 220
# https://www.ycombinator.com/companies/flex
# Processing company martin at index 221
# https://www.ycombinator.com/companies/martin
# Processing company healthtech-1 at index 222
# https://www.ycombinator.com/companies/healthtech-1
# Processing company feanix-biotechnologies at index 223
# https://www.ycombinator.com/companies/feanix-biotechnologies
# Processing company orbio-earth at index 224
# https://www.ycombinator.com/companies/orbio-earth
# Processing company codestory at index 225
# https://www.ycombinator.com/companies/codestory
# Processing company catx at index 226
# https://www.ycombinator.com/companies/catx
# Processing company coba at index 227
# https://www.ycombinator.com/companies/coba
# Processing company taylor-ai at index 228
# https://www.ycombinator.com/companies/taylor-ai
# Processing company tempo-labs at index 229
# https://www.ycombinator.com/companies/tempo-labs
# Processing company trendup at index 230
# https://www.ycombinator.com/companies/trendup
# Processing company autotab at index 231
# https://www.ycombinator.com/companies/autotab
# Processing company flair-health at index 232
# https://www.ycombinator.com/companies/flair-health
# Processing company olio-labs at index 233
# https://www.ycombinator.com/companies/olio-labs
# Processing company truemetrics at index 234
# https://www.ycombinator.com/companies/truemetrics
# Processing company onward at index 235
# https://www.ycombinator.com/companies/onward
# Processing company walletkit at index 236
# https://www.ycombinator.com/companies/walletkit
# Processing company wattson-health at index 237
# https://www.ycombinator.com/companies/wattson-health
# Processing company constructable at index 238
# https://www.ycombinator.com/companies/constructable
# Processing company innkeeper at index 239
# https://www.ycombinator.com/companies/innkeeper
# Processing company nowadays at index 240
# https://www.ycombinator.com/companies/nowadays
# Processing company structured at index 241
# https://www.ycombinator.com/companies/structured
# Processing company twine at index 242
# https://www.ycombinator.com/companies/twine
# Processing company axflow at index 243
# https://www.ycombinator.com/companies/axflow
# Processing company simbie-health at index 244
# https://www.ycombinator.com/companies/simbie-health
# Processing company foundation at index 245
# Processing company aisdr at index 246
# https://www.ycombinator.com/companies/aisdr
# Processing company giga-ml at index 247
# https://www.ycombinator.com/companies/giga-ml
# Processing company sero-ai at index 248
# https://www.ycombinator.com/companies/sero-ai
# Processing company affinity at index 249
# https://www.ycombinator.com/companies/affinity
# Processing company flowiseai at index 250
# https://www.ycombinator.com/companies/flowiseai
# Processing company shadeform at index 251
# https://www.ycombinator.com/companies/shadeform
# Processing company ten at index 252
# https://www.ycombinator.com/companies/ten
# Processing company kips-health at index 253
# https://www.ycombinator.com/companies/kips-health
# Processing company cargo at index 254
# https://www.ycombinator.com/companies/cargo
# Processing company chequpi at index 255
# https://www.ycombinator.com/companies/chequpi
# Processing company roame at index 256
# https://www.ycombinator.com/companies/roame
# Processing company trayd at index 259
# https://www.ycombinator.com/companies/trayd
# Processing company cair-health at index 260
# https://www.ycombinator.com/companies/cair-health
# Processing company paradedb at index 261
# https://www.ycombinator.com/companies/paradedb
# Processing company eden-care at index 262
# https://www.ycombinator.com/companies/eden-care
# Processing company quill-ai at index 263
# https://www.ycombinator.com/companies/quill-ai
# Processing company strada at index 264
# https://www.ycombinator.com/companies/strada
# Processing company agentsforce at index 265
# https://www.ycombinator.com/companies/agentsforce
# Processing company smobi at index 266
# https://www.ycombinator.com/companies/smobi
# Processing company tiptap at index 267
# https://www.ycombinator.com/companies/tiptap
# Processing company recipeui at index 268
# https://www.ycombinator.com/companies/recipeui
# Processing company fiber-ai at index 269
# https://www.ycombinator.com/companies/fiber-ai
# Processing company opsberry-ai at index 270
# https://www.ycombinator.com/companies/opsberry-ai
# Processing company certainly-health at index 271
# https://www.ycombinator.com/companies/certainly-health
# Processing company cedalio at index 272
# https://www.ycombinator.com/companies/cedalio
# Processing company happyrobot at index 273
# https://www.ycombinator.com/companies/happyrobot
# Processing company pure at index 274
# https://www.ycombinator.com/companies/pure
# Processing company nanograb at index 275
# https://www.ycombinator.com/companies/nanograb
# Processing company elythea at index 276
# https://www.ycombinator.com/companies/elythea
# Processing company movley at index 277
# https://www.ycombinator.com/companies/movley
# Processing company santé at index 278
# Processing company langdock at index 279
# https://www.ycombinator.com/companies/langdock
# Processing company inventive-ai at index 280
# https://www.ycombinator.com/companies/inventive-ai
# Processing company devmark at index 281
# https://www.ycombinator.com/companies/devmark
# Processing company fragment at index 282
# https://www.ycombinator.com/companies/fragment
# Processing company raz at index 283
# https://www.ycombinator.com/companies/raz
# Processing company sudocode at index 284
# https://www.ycombinator.com/companies/sudocode
# Processing company sweep at index 285
# https://www.ycombinator.com/companies/sweep
# Processing company silimate at index 286
# https://www.ycombinator.com/companies/silimate
# Processing company andromeda-surgical at index 287
# https://www.ycombinator.com/companies/andromeda-surgical
# Processing company prodtrace at index 288
# https://www.ycombinator.com/companies/prodtrace
# Processing company inari at index 289
# https://www.ycombinator.com/companies/inari
# Processing company roundtable at index 290
# https://www.ycombinator.com/companies/roundtable
# Processing company chatter at index 291
# https://www.ycombinator.com/companies/chatter
# Processing company trench at index 292
# https://www.ycombinator.com/companies/trench
# Processing company envelope at index 293
# https://www.ycombinator.com/companies/envelope
# Processing company vectorshift at index 294
# https://www.ycombinator.com/companies/vectorshift
# Processing company safetykit at index 295
# https://www.ycombinator.com/companies/safetykit
# Processing company baserun at index 296
# https://www.ycombinator.com/companies/baserun
# Processing company automorphic at index 297
# https://www.ycombinator.com/companies/automorphic
# Processing company glaze at index 298
# https://www.ycombinator.com/companies/glaze
# Processing company sola at index 299
# https://www.ycombinator.com/companies/sola
# Processing company inlet at index 300
# Processing company converge at index 301
# https://www.ycombinator.com/companies/converge
# Processing company flint at index 302
# https://www.ycombinator.com/companies/flint
# Processing company cambioml at index 303
# https://www.ycombinator.com/companies/cambioml
# Processing company osium-ai at index 304
# https://www.ycombinator.com/companies/osium-ai
# Processing company slicker at index 305
# https://www.ycombinator.com/companies/slicker
# Processing company khoj at index 306
# https://www.ycombinator.com/companies/khoj
# Processing company vaultpay at index 307
# https://www.ycombinator.com/companies/vaultpay
# Processing company crew at index 308
# https://www.ycombinator.com/companies/crew
# Processing company gleam at index 309
# https://www.ycombinator.com/companies/gleam
# Processing company kobalt-labs at index 310
# https://www.ycombinator.com/companies/kobalt-labs
# Processing company studdy at index 311
# https://www.ycombinator.com/companies/studdy
# Processing company trainy at index 312
# https://www.ycombinator.com/companies/trainy
# Processing company mantlebio at index 313
# https://www.ycombinator.com/companies/mantlebio
# Processing company pincites at index 314
# https://www.ycombinator.com/companies/pincites
# Processing company apoxy at index 315
# https://www.ycombinator.com/companies/apoxy
# Processing company sizeless at index 316
# https://www.ycombinator.com/companies/sizeless
# Processing company quack-ai at index 317
# https://www.ycombinator.com/companies/quack-ai
# Processing company continue at index 318
# https://www.ycombinator.com/companies/continue
# Processing company letter-ai at index 319
# https://www.ycombinator.com/companies/letter-ai
# Processing company guac at index 320
# https://www.ycombinator.com/companies/guac
# Processing company casehopper at index 321
# https://www.ycombinator.com/companies/casehopper
# Processing company glade at index 322
# https://www.ycombinator.com/companies/glade
# Processing company lifestylerx at index 323
# https://www.ycombinator.com/companies/lifestylerx
# Processing company empirical-health at index 324
# https://www.ycombinator.com/companies/empirical-health
# Processing company fortuna-health at index 325
# https://www.ycombinator.com/companies/fortuna-health
# Processing company aglide at index 326
# https://www.ycombinator.com/companies/aglide
# Processing company respaid at index 327
# https://www.ycombinator.com/companies/respaid
# Processing company vizly at index 328
# https://www.ycombinator.com/companies/vizly
# Processing company revideo at index 329
# https://www.ycombinator.com/companies/revideo
# Processing company greenlite at index 330
# https://www.ycombinator.com/companies/greenlite
# Processing company medisearch at index 331
# https://www.ycombinator.com/companies/medisearch
# Processing company metalware at index 332
# https://www.ycombinator.com/companies/metalware
# Processing company upstream at index 333
# https://www.ycombinator.com/companies/upstream
# Processing company maven-bio at index 334
# https://www.ycombinator.com/companies/maven-bio
# Processing company egress at index 335
# https://www.ycombinator.com/companies/egress
# Processing company surface-labs at index 336
# https://www.ycombinator.com/companies/surface-labs
# Processing company unhaze at index 337
# https://www.ycombinator.com/companies/unhaze
# Processing company candoriq at index 338
# https://www.ycombinator.com/companies/candoriq
# Processing company refine at index 339
# https://www.ycombinator.com/companies/refine
# Processing company epsilla at index 340
# https://www.ycombinator.com/companies/epsilla
# Processing company camber at index 341
# https://www.ycombinator.com/companies/camber
# Processing company vetrec at index 342
# https://www.ycombinator.com/companies/vetrec
# Processing company cleancard at index 343
# https://www.ycombinator.com/companies/cleancard
# Processing company decoda-health at index 344
# https://www.ycombinator.com/companies/decoda-health
# Processing company skyvern at index 345
# https://www.ycombinator.com/companies/skyvern
# Processing company cardinal-gray at index 346
# https://www.ycombinator.com/companies/cardinal-gray
# Processing company telophase at index 347
# https://www.ycombinator.com/companies/telophase
# Processing company anneal at index 348
# https://www.ycombinator.com/companies/anneal
# Processing company transformity at index 349
# https://www.ycombinator.com/companies/transformity
# Processing company repaint at index 350
# https://www.ycombinator.com/companies/repaint
# Processing company chow-central-inc at index 351
# https://www.ycombinator.com/companies/chow-central-inc
# Processing company fleetworks at index 352
# https://www.ycombinator.com/companies/fleetworks
# Processing company menza at index 353
# https://www.ycombinator.com/companies/menza
# Processing company health-harbor at index 354
# https://www.ycombinator.com/companies/health-harbor
# Processing company briefer at index 355
# https://www.ycombinator.com/companies/briefer
# Processing company shasta-health at index 356
# https://www.ycombinator.com/companies/shasta-health
# Processing company hegel-ai at index 357
# https://www.ycombinator.com/companies/hegel-ai
# Processing company outset at index 358
# https://www.ycombinator.com/companies/outset
# Processing company serra at index 359
# https://www.ycombinator.com/companies/serra
# Processing company corgea at index 360
# https://www.ycombinator.com/companies/corgea
# Processing company terminal at index 361
# https://www.ycombinator.com/companies/terminal
# Processing company micsi at index 362
# https://www.ycombinator.com/companies/micsi
# Processing company craftos at index 363
# https://www.ycombinator.com/companies/craftos
# Processing company arcimus at index 364
# https://www.ycombinator.com/companies/arcimus
# Processing company docsum at index 365
# https://www.ycombinator.com/companies/docsum
# Processing company obento-health at index 366
# https://www.ycombinator.com/companies/obento-health
# Processing company kite at index 367
# https://www.ycombinator.com/companies/kite
# Processing company bronco-ai at index 368
# https://www.ycombinator.com/companies/bronco-ai
# Processing company agentive at index 369
# https://www.ycombinator.com/companies/agentive
# Processing company venta at index 370
# https://www.ycombinator.com/companies/venta
# Processing company parea at index 371
# https://www.ycombinator.com/companies/parea
# Processing company campfire at index 372
# https://www.ycombinator.com/companies/campfire
# Processing company alguna at index 373
# https://www.ycombinator.com/companies/alguna
# Processing company sid at index 374
# https://www.ycombinator.com/companies/sid
# Processing company capi-money at index 375
# https://www.ycombinator.com/companies/capi-money
# Processing company cerelyze at index 376
# https://www.ycombinator.com/companies/cerelyze
# Processing company spine-ai at index 377
# https://www.ycombinator.com/companies/spine-ai
# Processing company empower at index 378
# https://www.ycombinator.com/companies/empower
# Processing company subsets at index 379
# https://www.ycombinator.com/companies/subsets
# Processing company mira at index 380
# https://www.ycombinator.com/companies/mira
# Processing company synch at index 381
# https://www.ycombinator.com/companies/synch
# Processing company revamp at index 382
# https://www.ycombinator.com/companies/revamp
# Processing company datashare at index 383
# https://www.ycombinator.com/companies/datashare
# Processing company airgoods at index 384
# https://www.ycombinator.com/companies/airgoods
# Processing company talc at index 385
# https://www.ycombinator.com/companies/talc
# Processing company solve-intelligence at index 386
# https://www.ycombinator.com/companies/solve-intelligence
# Processing company asklio at index 387
# https://www.ycombinator.com/companies/asklio
# Processing company craftwork at index 388
# https://www.ycombinator.com/companies/craftwork
# Processing company electric-air- at index 389
# Processing company fynt-ai at index 390
# https://www.ycombinator.com/companies/fynt-ai
# Processing company every at index 391
# https://www.ycombinator.com/companies/every
# Processing company contour at index 392
# https://www.ycombinator.com/companies/contour
# Processing company atla at index 393
# https://www.ycombinator.com/companies/atla
# Processing company humanlike at index 394
# https://www.ycombinator.com/companies/humanlike
# Processing company lifelike at index 395
# https://www.ycombinator.com/companies/lifelike
# Processing company cedana at index 396
# https://www.ycombinator.com/companies/cedana
# Processing company cascading-ai at index 397
# https://www.ycombinator.com/companies/cascading-ai
# Processing company zelos-cloud at index 398
# https://www.ycombinator.com/companies/zelos-cloud
# Processing company pandan at index 399
# https://www.ycombinator.com/companies/pandan
# Processing company proprise at index 400
# https://www.ycombinator.com/companies/proprise
# Processing company pointhound at index 401
# https://www.ycombinator.com/companies/pointhound
# Processing company diligent at index 402
# https://www.ycombinator.com/companies/diligent
# Processing company intelliga-voice at index 403
# https://www.ycombinator.com/companies/intelliga-voice
# Processing company sohar-health at index 404
# https://www.ycombinator.com/companies/sohar-health
# Processing company remy at index 405
# https://www.ycombinator.com/companies/remy
# Processing company sweetspot at index 406
# https://www.ycombinator.com/companies/sweetspot
# Processing company magic-loops at index 407
# https://www.ycombinator.com/companies/magic-loops
# Processing company ohmic-biosciences at index 408
# https://www.ycombinator.com/companies/ohmic-biosciences
# Processing company stellar-sleep at index 409
# https://www.ycombinator.com/companies/stellar-sleep
# Processing company infobot at index 410
# https://www.ycombinator.com/companies/infobot
# Processing company linc- at index 411
# Processing company watto-ai at index 412
# https://www.ycombinator.com/companies/watto-ai
# Processing company dioxus-labs at index 413
# https://www.ycombinator.com/companies/dioxus-labs
# Processing company hyperbound at index 414
# https://www.ycombinator.com/companies/hyperbound
# Processing company deasie at index 415
# https://www.ycombinator.com/companies/deasie
# Processing company accend at index 416
# https://www.ycombinator.com/companies/accend
# Processing company elyos-energy at index 417
# https://www.ycombinator.com/companies/elyos-energy
# Processing company mano-ai at index 418
# https://www.ycombinator.com/companies/mano-ai
# Processing company metoro at index 419
# https://www.ycombinator.com/companies/metoro
# Processing company xeol at index 420
# https://www.ycombinator.com/companies/xeol
# Processing company twenty at index 421
# https://www.ycombinator.com/companies/twenty
# Processing company synaptiq at index 422
# https://www.ycombinator.com/companies/synaptiq
# Processing company branch-ai at index 423
# https://www.ycombinator.com/companies/branch-ai
# Processing company nectar at index 424
# https://www.ycombinator.com/companies/nectar
# Processing company reworkd at index 425
# https://www.ycombinator.com/companies/reworkd
# Processing company leafpress at index 426
# https://www.ycombinator.com/companies/leafpress
# Processing company kino-ai at index 427
# https://www.ycombinator.com/companies/kino-ai
# Processing company kapa-ai at index 428
# https://www.ycombinator.com/companies/kapa-ai
# Processing company tremor at index 429
# https://www.ycombinator.com/companies/tremor
# Processing company peerdb at index 430
# https://www.ycombinator.com/companies/peerdb
# Processing company artie at index 431
# https://www.ycombinator.com/companies/artie
# Processing company hylight at index 432
# https://www.ycombinator.com/companies/hylight
# Processing company hockeystack at index 433
# https://www.ycombinator.com/companies/hockeystack
# Processing company can-of-soup at index 434
# https://www.ycombinator.com/companies/can-of-soup
# Processing company cercli at index 435
# https://www.ycombinator.com/companies/cercli
# Processing company line-build at index 436
# https://www.ycombinator.com/companies/line-build
# Processing company vango-ai at index 437
# https://www.ycombinator.com/companies/vango-ai
# Processing company sidenote at index 438
# https://www.ycombinator.com/companies/sidenote
# Processing company pando-bioscience at index 439
# https://www.ycombinator.com/companies/pando-bioscience
# Processing company metal at index 440
# https://www.ycombinator.com/companies/metal
# Processing company vaero at index 441
# https://www.ycombinator.com/companies/vaero
# Processing company yuma at index 442
# https://www.ycombinator.com/companies/yuma
# Processing company pierre at index 443
# https://www.ycombinator.com/companies/pierre
# Processing company moonrepo at index 444
# https://www.ycombinator.com/companies/moonrepo
# Processing company automat at index 445
# https://www.ycombinator.com/companies/automat
# Processing company speccheck at index 446
# https://www.ycombinator.com/companies/speccheck
# Processing company speedybrand at index 447
# https://www.ycombinator.com/companies/speedybrand
# Processing company finta at index 448
# https://www.ycombinator.com/companies/finta
# Processing company berriai at index 449
# https://www.ycombinator.com/companies/berriai
# Processing company theya at index 450
# https://www.ycombinator.com/companies/theya
# Processing company upfront at index 451
# https://www.ycombinator.com/companies/upfront
# Processing company kopia at index 452
# https://www.ycombinator.com/companies/kopia
# Processing company warp at index 453
# https://www.ycombinator.com/companies/warp
# Processing company second at index 454
# https://www.ycombinator.com/companies/second
# Processing company atri-labs at index 455
# https://www.ycombinator.com/companies/atri-labs
# Processing company vendora at index 456
# https://www.ycombinator.com/companies/vendora
# Processing company lightski at index 457
# https://www.ycombinator.com/companies/lightski
# Processing company type at index 458
# https://www.ycombinator.com/companies/type
# Processing company meru at index 459
# https://www.ycombinator.com/companies/meru
# Processing company persana-ai at index 460
# https://www.ycombinator.com/companies/persana-ai
# Processing company serial at index 461
# https://www.ycombinator.com/companies/serial
# Processing company kyber at index 462
# https://www.ycombinator.com/companies/kyber
# Processing company escape at index 463
# https://www.ycombinator.com/companies/escape
# Processing company keeling-labs at index 464
# https://www.ycombinator.com/companies/keeling-labs
# Processing company modulari-t at index 465
# https://www.ycombinator.com/companies/modulari-t
# Processing company koala-ops at index 466
# https://www.ycombinator.com/companies/koala-ops
# Processing company metal at index 467
# https://www.ycombinator.com/companies/metal
# Processing company texel-ai at index 468
# https://www.ycombinator.com/companies/texel-ai
# Processing company vector at index 469
# https://www.ycombinator.com/companies/vector
# Processing company pier at index 470
# https://www.ycombinator.com/companies/pier
# Processing company aiflow at index 471
# https://www.ycombinator.com/companies/aiflow
# Processing company finni-health at index 472
# https://www.ycombinator.com/companies/finni-health
# Processing company invitris at index 473
# https://www.ycombinator.com/companies/invitris
# Processing company adventris-pharmaceuticals at index 474
# https://www.ycombinator.com/companies/adventris-pharmaceuticals
# Processing company highlight-io at index 475
# https://www.ycombinator.com/companies/highlight-io
# Processing company untether-labs at index 476
# https://www.ycombinator.com/companies/untether-labs
# Processing company luca at index 477
# https://www.ycombinator.com/companies/luca
# Processing company edge at index 478
# https://www.ycombinator.com/companies/edge
# Processing company benchmark at index 479
# https://www.ycombinator.com/companies/benchmark
# Processing company fabius at index 480
# https://www.ycombinator.com/companies/fabius
# Processing company vocode at index 481
# https://www.ycombinator.com/companies/vocode
# Processing company wallbit at index 482
# https://www.ycombinator.com/companies/wallbit
# Processing company vellum at index 483
# https://www.ycombinator.com/companies/vellum
# Processing company rex at index 484
# https://www.ycombinator.com/companies/rex
# Processing company persist-ai at index 485
# https://www.ycombinator.com/companies/persist-ai
# Processing company berry at index 486
# https://www.ycombinator.com/companies/berry
# Processing company conduit at index 487
# https://www.ycombinator.com/companies/conduit
# Processing company codeparrot at index 488
# https://www.ycombinator.com/companies/codeparrot
# Processing company superapi at index 489
# https://www.ycombinator.com/companies/superapi
# Processing company fern at index 490
# https://www.ycombinator.com/companies/fern
# Processing company unstatiq at index 491
# https://www.ycombinator.com/companies/unstatiq
# Processing company resend at index 492
# https://www.ycombinator.com/companies/resend
# Processing company decohere at index 493
# https://www.ycombinator.com/companies/decohere
# Processing company ally at index 494
# https://www.ycombinator.com/companies/ally
# Processing company constant at index 495
# https://www.ycombinator.com/companies/constant
# Processing company common-paper at index 496
# https://www.ycombinator.com/companies/common-paper
# Processing company dill at index 497
# https://www.ycombinator.com/companies/dill
# Processing company dealpage at index 498
# https://www.ycombinator.com/companies/dealpage
# Processing company littio at index 499
# https://www.ycombinator.com/companies/littio
# Processing company thread at index 500
# https://www.ycombinator.com/companies/thread
# Processing company waza at index 501
# https://www.ycombinator.com/companies/waza
# Processing company rivet at index 502
# https://www.ycombinator.com/companies/rivet
# Processing company sorted at index 503
# https://www.ycombinator.com/companies/sorted
# Processing company dagworks-inc- at index 504
# Processing company swishjam at index 505
# https://www.ycombinator.com/companies/swishjam
# Processing company invopop at index 506
# https://www.ycombinator.com/companies/invopop
# Processing company turntable at index 507
# https://www.ycombinator.com/companies/turntable
# Processing company corgi-labs at index 508
# https://www.ycombinator.com/companies/corgi-labs
# Processing company stralis-aircraft at index 509
# https://www.ycombinator.com/companies/stralis-aircraft
# Processing company keep at index 510
# https://www.ycombinator.com/companies/keep
# Processing company play at index 511
# https://www.ycombinator.com/companies/play
# Processing company holacasa at index 512
# https://www.ycombinator.com/companies/holacasa
# Processing company epsilon at index 513
# https://www.ycombinator.com/companies/epsilon
# Processing company clad at index 514
# https://www.ycombinator.com/companies/clad
# Processing company pylon at index 515
# https://www.ycombinator.com/companies/pylon
# Processing company muffin-data at index 516
# https://www.ycombinator.com/companies/muffin-data
# Processing company peeba at index 517
# https://www.ycombinator.com/companies/peeba
# Processing company diffuse-bio at index 518
# https://www.ycombinator.com/companies/diffuse-bio
# Processing company inbuild at index 519
# https://www.ycombinator.com/companies/inbuild
# Processing company sanvivo at index 520
# https://www.ycombinator.com/companies/sanvivo
# Processing company clearspace at index 521
# https://www.ycombinator.com/companies/clearspace
# Processing company univerbal- at index 522
# Processing company milio at index 523
# https://www.ycombinator.com/companies/milio
# Processing company mantys at index 524
# https://www.ycombinator.com/companies/mantys
# Processing company proglix at index 525
# https://www.ycombinator.com/companies/proglix
# Processing company coldreach at index 526
# https://www.ycombinator.com/companies/coldreach
# Processing company magnaplay at index 527
# https://www.ycombinator.com/companies/magnaplay
# Processing company shekel-mobility at index 528
# https://www.ycombinator.com/companies/shekel-mobility
# Processing company inri at index 529
# https://www.ycombinator.com/companies/inri
# Processing company loula at index 530
# https://www.ycombinator.com/companies/loula
# Processing company sirdab at index 531
# https://www.ycombinator.com/companies/sirdab
# Processing company baselit at index 532
# https://www.ycombinator.com/companies/baselit
# Processing company clueso at index 533
# https://www.ycombinator.com/companies/clueso
# Processing company superkalam at index 534
# https://www.ycombinator.com/companies/superkalam
# Processing company fastgen at index 535
# https://www.ycombinator.com/companies/fastgen
# Processing company arroyo at index 536
# https://www.ycombinator.com/companies/arroyo
# Processing company vendah at index 537
# https://www.ycombinator.com/companies/vendah
# Processing company alaan at index 538
# https://www.ycombinator.com/companies/alaan
# Processing company echo at index 539
# https://www.ycombinator.com/companies/echo
# Processing company uptrain-ai at index 540
# https://www.ycombinator.com/companies/uptrain-ai
# Processing company keyval at index 541
# https://www.ycombinator.com/companies/keyval
# Processing company nunu-ai at index 542
# https://www.ycombinator.com/companies/nunu-ai
# Processing company hona at index 543
# https://www.ycombinator.com/companies/hona
# Processing company radical at index 544
# https://www.ycombinator.com/companies/radical
# Processing company vitalize-care at index 545
# https://www.ycombinator.com/companies/vitalize-care
# Processing company noya-software at index 546
# https://www.ycombinator.com/companies/noya-software
# Processing company infinia at index 547
# https://www.ycombinator.com/companies/infinia
# Processing company koywe at index 548
# https://www.ycombinator.com/companies/koywe
# Processing company dealwise at index 549
# https://www.ycombinator.com/companies/dealwise
# Processing company honeydew at index 550
# https://www.ycombinator.com/companies/honeydew
# Processing company sherloq at index 551
# https://www.ycombinator.com/companies/sherloq
# Processing company sprx at index 552
# https://www.ycombinator.com/companies/sprx
# Processing company shortbread at index 553
# https://www.ycombinator.com/companies/shortbread
# Processing company pointwise at index 554
# https://www.ycombinator.com/companies/pointwise
# Processing company fairway-health at index 555
# https://www.ycombinator.com/companies/fairway-health
# Processing company hadrius at index 556
# https://www.ycombinator.com/companies/hadrius
# Processing company technician at index 557
# https://www.ycombinator.com/companies/technician
# Processing company sage-ai at index 558
# https://www.ycombinator.com/companies/sage-ai
# ...
# Processing company singlestore at index 4384
# https://www.ycombinator.com/companies/singlestore
# Processing company fivestars at index 4385
# https://www.ycombinator.com/companies/fivestars
# Processing company hellosign at index 4386
# https://www.ycombinator.com/companies/hellosign
# Processing company drchrono at index 4387
# https://www.ycombinator.com/companies/drchrono
# Processing company zerocater at index 4388
# https://www.ycombinator.com/companies/zerocater
# Processing company storyworth at index 4389
# https://www.ycombinator.com/companies/storyworth
# Processing company mino-games at index 4390
# https://www.ycombinator.com/companies/mino-games
# Processing company close at index 4391
# https://www.ycombinator.com/companies/close
# Processing company tremendous at index 4392
# https://www.ycombinator.com/companies/tremendous
# Processing company you-got-listings at index 4393
# Processing company instapainting at index 4394
# https://www.ycombinator.com/companies/instapainting
# Processing company acunote at index 4395
# https://www.ycombinator.com/companies/acunote
# Processing company tumult at index 4396
# https://www.ycombinator.com/companies/tumult
# Processing company talkable at index 4397
# https://www.ycombinator.com/companies/talkable
# Processing company talkbin at index 4398
# https://www.ycombinator.com/companies/talkbin
# Processing company orderahead at index 4399
# https://www.ycombinator.com/companies/orderahead
# Processing company lanyrd at index 4400
# https://www.ycombinator.com/companies/lanyrd
# Processing company mailgun at index 4401
# https://www.ycombinator.com/companies/mailgun
# Processing company apportable at index 4402
# https://www.ycombinator.com/companies/apportable
# Processing company pebble at index 4403
# https://www.ycombinator.com/companies/pebble
# Processing company humble-bundle at index 4404
# https://www.ycombinator.com/companies/humble-bundle
# Processing company comprehend at index 4405
# https://www.ycombinator.com/companies/comprehend
# Processing company custora at index 4406
# https://www.ycombinator.com/companies/custora
# Processing company hotspots at index 4407
# https://www.ycombinator.com/companies/hotspots
# Processing company sendoid at index 4408
# https://www.ycombinator.com/companies/sendoid
# Processing company earbits at index 4409
# https://www.ycombinator.com/companies/earbits
# Processing company upverter at index 4410
# https://www.ycombinator.com/companies/upverter
# Processing company simplylisted at index 4411
# https://www.ycombinator.com/companies/simplylisted
# Processing company venuetastic at index 4412
# https://www.ycombinator.com/companies/venuetastic
# Processing company siasto at index 4413
# https://www.ycombinator.com/companies/siasto
# Processing company trustegg at index 4414
# https://www.ycombinator.com/companies/trustegg
# Processing company tutorspree at index 4415
# https://www.ycombinator.com/companies/tutorspree
# Processing company balanced at index 4416
# https://www.ycombinator.com/companies/balanced
# Processing company flotype at index 4417
# https://www.ycombinator.com/companies/flotype
# Processing company convore at index 4418
# https://www.ycombinator.com/companies/convore
# Processing company insight-data-science at index 4419
# https://www.ycombinator.com/companies/insight-data-science
# Processing company hyperink at index 4420
# https://www.ycombinator.com/companies/hyperink
# Processing company appharbor at index 4421
# https://www.ycombinator.com/companies/appharbor
# Processing company fitfu at index 4422
# https://www.ycombinator.com/companies/fitfu
# Processing company assembled at index 4423
# https://www.ycombinator.com/companies/assembled
# Processing company tellfi at index 4424
# https://www.ycombinator.com/companies/tellfi
# Processing company beetailer at index 4425
# https://www.ycombinator.com/companies/beetailer
# Processing company inporia at index 4426
# https://www.ycombinator.com/companies/inporia
# Processing company userfox at index 4427
# https://www.ycombinator.com/companies/userfox
# Processing company pagerduty at index 4428
# https://www.ycombinator.com/companies/pagerduty
# Processing company presto at index 4429
# https://www.ycombinator.com/companies/presto
# Processing company docker at index 4430
# https://www.ycombinator.com/companies/docker
# Processing company futureadvisor at index 4431
# https://www.ycombinator.com/companies/futureadvisor
# Processing company workflowy at index 4432
# https://www.ycombinator.com/companies/workflowy
# Processing company indinero at index 4433
# https://www.ycombinator.com/companies/indinero
# Processing company anylist at index 4434
# https://www.ycombinator.com/companies/anylist
# Processing company demandsphere at index 4435
# https://www.ycombinator.com/companies/demandsphere
# Processing company recurse-center at index 4436
# https://www.ycombinator.com/companies/recurse-center
# Processing company adgrok at index 4437
# https://www.ycombinator.com/companies/adgrok
# Processing company whereoscope at index 4438
# https://www.ycombinator.com/companies/whereoscope
# Processing company tapzilla at index 4439
# https://www.ycombinator.com/companies/tapzilla
# Processing company fridge at index 4440
# https://www.ycombinator.com/companies/fridge
# Processing company fanvibe at index 4441
# https://www.ycombinator.com/companies/fanvibe
# Processing company leftronic at index 4442
# https://www.ycombinator.com/companies/leftronic
# Processing company gazehawk at index 4443
# https://www.ycombinator.com/companies/gazehawk
# Processing company 1000memories at index 4444
# https://www.ycombinator.com/companies/1000memories
# Processing company homejoy at index 4445
# https://www.ycombinator.com/companies/homejoy
# Processing company padmapper at index 4446
# https://www.ycombinator.com/companies/padmapper
# Processing company aerofs at index 4447
# https://www.ycombinator.com/companies/aerofs
# Processing company simperium at index 4448
# https://www.ycombinator.com/companies/simperium
# Processing company rapportive at index 4449
# https://www.ycombinator.com/companies/rapportive
# Processing company hipmunk at index 4450
# https://www.ycombinator.com/companies/hipmunk
# Processing company chartio at index 4451
# https://www.ycombinator.com/companies/chartio
# Processing company koduco at index 4452
# https://www.ycombinator.com/companies/koduco
# Processing company pribbit at index 4453
# https://www.ycombinator.com/companies/pribbit
# Processing company messageparty at index 4454
# https://www.ycombinator.com/companies/messageparty
# Processing company ready-for-zero at index 4455
# https://www.ycombinator.com/companies/ready-for-zero
# Processing company post-fm at index 4456
# https://www.ycombinator.com/companies/post-fm
# Processing company opzi at index 4457
# https://www.ycombinator.com/companies/opzi
# Processing company upbeat at index 4458
# https://www.ycombinator.com/companies/upbeat
# Processing company gantto at index 4459
# https://www.ycombinator.com/companies/gantto
# Processing company brushes at index 4460
# https://www.ycombinator.com/companies/brushes
# Processing company habit-labs at index 4461
# https://www.ycombinator.com/companies/habit-labs
# Processing company chirply at index 4462
# https://www.ycombinator.com/companies/chirply
# Processing company teevox at index 4463
# https://www.ycombinator.com/companies/teevox
# Processing company optimizely at index 4464
# https://www.ycombinator.com/companies/optimizely
# Processing company ownlocal at index 4465
# https://www.ycombinator.com/companies/ownlocal
# Processing company etacts at index 4466
# https://www.ycombinator.com/companies/etacts
# Processing company movity at index 4467
# https://www.ycombinator.com/companies/movity
# Processing company cardpool at index 4468
# https://www.ycombinator.com/companies/cardpool
# Processing company cue at index 4469
# https://www.ycombinator.com/companies/cue
# Processing company zencoder at index 4470
# https://www.ycombinator.com/companies/zencoder
# Processing company nowmov at index 4471
# https://www.ycombinator.com/companies/nowmov
# Processing company creative-market at index 4472
# https://www.ycombinator.com/companies/creative-market
# Processing company embedly at index 4473
# https://www.ycombinator.com/companies/embedly
# Processing company bitplay at index 4474
# https://www.ycombinator.com/companies/bitplay
# Processing company crocodoc at index 4475
# https://www.ycombinator.com/companies/crocodoc
# Processing company all-screen at index 4476
# https://www.ycombinator.com/companies/all-screen
# Processing company 500friends at index 4477
# https://www.ycombinator.com/companies/500friends
# Processing company mertado at index 4478
# https://www.ycombinator.com/companies/mertado
# Processing company mixed-media-labs at index 4479
# Processing company notifo at index 4480
# https://www.ycombinator.com/companies/notifo
# Processing company infoharmoni at index 4481
# https://www.ycombinator.com/companies/infoharmoni
# Processing company newcope at index 4482
# https://www.ycombinator.com/companies/newcope
# Processing company newslabs at index 4483
# https://www.ycombinator.com/companies/newslabs
# Processing company data-marketplace at index 4484
# https://www.ycombinator.com/companies/data-marketplace
# Processing company fithub at index 4485
# https://www.ycombinator.com/companies/fithub
# Processing company gamador at index 4486
# https://www.ycombinator.com/companies/gamador
# Processing company zenedy at index 4487
# https://www.ycombinator.com/companies/zenedy
# Processing company answerly at index 4488
# https://www.ycombinator.com/companies/answerly
# Processing company launchhear at index 4489
# https://www.ycombinator.com/companies/launchhear
# Processing company fabricly at index 4490
# https://www.ycombinator.com/companies/fabricly
# Processing company stripe at index 4491
# https://www.ycombinator.com/companies/stripe
# Processing company mixpanel at index 4492
# https://www.ycombinator.com/companies/mixpanel
# Processing company wepay at index 4493
# https://www.ycombinator.com/companies/wepay
# Processing company lingt at index 4494
# https://www.ycombinator.com/companies/lingt
# Processing company renthop at index 4495
# https://www.ycombinator.com/companies/renthop
# Processing company olark at index 4496
# https://www.ycombinator.com/companies/olark
# Processing company directed-edge at index 4497
# https://www.ycombinator.com/companies/directed-edge
# Processing company listia at index 4498
# https://www.ycombinator.com/companies/listia
# Processing company flightcaster at index 4499
# https://www.ycombinator.com/companies/flightcaster
# Processing company graffitigeo at index 4500
# https://www.ycombinator.com/companies/graffitigeo
# Processing company lockitron at index 4501
# https://www.ycombinator.com/companies/lockitron
# Processing company rethinkdb at index 4502
# https://www.ycombinator.com/companies/rethinkdb
# Processing company bump at index 4503
# https://www.ycombinator.com/companies/bump
# Processing company dailybooth at index 4504
# https://www.ycombinator.com/companies/dailybooth
# Processing company instantq at index 4505
# https://www.ycombinator.com/companies/instantq
# Processing company wakemate at index 4506
# https://www.ycombinator.com/companies/wakemate
# Processing company stackq at index 4507
# https://www.ycombinator.com/companies/stackq
# Processing company adthrow at index 4508
# https://www.ycombinator.com/companies/adthrow
# Processing company robohr at index 4509
# https://www.ycombinator.com/companies/robohr
# Processing company nudgepad at index 4510
# https://www.ycombinator.com/companies/nudgepad
# Processing company plurchase at index 4511
# https://www.ycombinator.com/companies/plurchase
# Processing company fanchatter at index 4512
# https://www.ycombinator.com/companies/fanchatter
# Processing company ssovereign at index 4513
# https://www.ycombinator.com/companies/ssovereign
# Processing company carwoo at index 4514
# https://www.ycombinator.com/companies/carwoo
# Processing company jobspice at index 4515
# https://www.ycombinator.com/companies/jobspice
# Processing company highlightcam at index 4516
# https://www.ycombinator.com/companies/highlightcam
# Processing company airbnb at index 4517
# https://www.ycombinator.com/companies/airbnb
# Processing company volantio at index 4518
# https://www.ycombinator.com/companies/volantio
# Processing company wattvision at index 4519
# https://www.ycombinator.com/companies/wattvision
# Processing company cloudkick at index 4520
# https://www.ycombinator.com/companies/cloudkick
# Processing company echodio at index 4521
# https://www.ycombinator.com/companies/echodio
# Processing company remail at index 4522
# https://www.ycombinator.com/companies/remail
# Processing company divvyshot at index 4523
# https://www.ycombinator.com/companies/divvyshot
# Processing company heyzap at index 4524
# https://www.ycombinator.com/companies/heyzap
# Processing company petasales at index 4525
# https://www.ycombinator.com/companies/petasales
# Processing company voxli at index 4526
# https://www.ycombinator.com/companies/voxli
# Processing company nambii at index 4527
# https://www.ycombinator.com/companies/nambii
# Processing company picurio at index 4528
# https://www.ycombinator.com/companies/picurio
# Processing company spaces-life at index 4529
# https://www.ycombinator.com/companies/spaces-life
# Processing company foodoro at index 4530
# https://www.ycombinator.com/companies/foodoro
# Processing company skysheet at index 4531
# https://www.ycombinator.com/companies/skysheet
# Processing company recurious at index 4532
# https://www.ycombinator.com/companies/recurious
# Processing company poll-everywhere at index 4533
# https://www.ycombinator.com/companies/poll-everywhere
# Processing company backtype at index 4534
# https://www.ycombinator.com/companies/backtype
# Processing company justspotted at index 4535
# https://www.ycombinator.com/companies/justspotted
# Processing company cloudant at index 4536
# https://www.ycombinator.com/companies/cloudant
# Processing company posterous at index 4537
# https://www.ycombinator.com/companies/posterous
# Processing company slinkset at index 4538
# https://www.ycombinator.com/companies/slinkset
# Processing company treehouse at index 4539
# https://www.ycombinator.com/companies/treehouse
# Processing company playreader at index 4540
# https://www.ycombinator.com/companies/playreader
# Processing company people-and-pages at index 4541
# https://www.ycombinator.com/companies/people-and-pages
# Processing company popcuts at index 4542
# https://www.ycombinator.com/companies/popcuts
# Processing company snipd at index 4543
# https://www.ycombinator.com/companies/snipd
# Processing company ticket-stumbler at index 4544
# https://www.ycombinator.com/companies/ticket-stumbler
# Processing company claimspotting at index 4545
# https://www.ycombinator.com/companies/claimspotting
# Processing company team-apart at index 4546
# https://www.ycombinator.com/companies/team-apart
# Processing company youlicit at index 4547
# https://www.ycombinator.com/companies/youlicit
# Processing company precognate at index 4548
# https://www.ycombinator.com/companies/precognate
# Processing company picwing at index 4549
# https://www.ycombinator.com/companies/picwing
# Processing company co2stats at index 4550
# https://www.ycombinator.com/companies/co2stats
# Processing company anyvite at index 4551
# https://www.ycombinator.com/companies/anyvite
# Processing company frogmetrics at index 4552
# https://www.ycombinator.com/companies/frogmetrics
# Processing company job-alchemist at index 4553
# https://www.ycombinator.com/companies/job-alchemist
# Processing company ohlife at index 4554
# https://www.ycombinator.com/companies/ohlife
# Processing company machine-zone at index 4555
# https://www.ycombinator.com/companies/machine-zone
# Processing company heroku at index 4556
# https://www.ycombinator.com/companies/heroku
# Processing company ninite at index 4557
# https://www.ycombinator.com/companies/ninite
# Processing company rescuetime at index 4558
# https://www.ycombinator.com/companies/rescuetime
# Processing company 280-north at index 4559
# https://www.ycombinator.com/companies/280-north
# Processing company omnisio at index 4560
# https://www.ycombinator.com/companies/omnisio
# Processing company a-thinking-ape at index 4561
# https://www.ycombinator.com/companies/a-thinking-ape
# Company data successfully updated.
# 179

# %% [markdown]
# ## As i see there is 179 company data is not updated with url
# ## To handle the situation where the company name in the URL might not exactly match the company name in the company_data
# ## So, implemented a fuzzy matching algorithm or a partial string matching algorithm. One popular library for this task is fuzzywuzzy.

# %%
from fuzzywuzzy import fuzz

# Set a threshold for similarity score
SIMILARITY_THRESHOLD = 50  # Adjust as needed

# List to store company names for which URLs are not updated
unmatched_company_names = []


# Update the URLs for each company
for company in company_not_updated:
    company_name = company.lower().replace(" ","-") # Convert company name to lowercase
    # Flag to check if URL is updated
    url_updated = False
    # Find the URL corresponding to the company name
    for key, value in company_url_map.items():
        if fuzz.partial_ratio(key.lower(), company_name) >= SIMILARITY_THRESHOLD:
            # Update the URL for the company
            for company in company_data:
                if company.get("Name", "").lower().replace(" ","-") == company_name:
                    company["url"] = value
                    print(value)
                    url_updated = True
                    break
    if url_updated==True:
        break
    # If URL is not updated, add company name to the list
    else:
        unmatched_company_names.append(company_name)

# Save updated company data to company_data.json
with open("company_data.json", "w") as json_file:
    json.dump(company_data, json_file, indent=4)

print("Company URLs added to company data and saved successfully.")

# Print unmatched company names
print("Company names for which URLs are not updated:", unmatched_company_names)
# Out:
# https://www.ycombinator.com/companies/mathgptpro
# https://www.ycombinator.com/companies/cocrafter
# https://www.ycombinator.com/companies/eris-biotech
# https://www.ycombinator.com/companies/arcane
# https://www.ycombinator.com/companies/vista-space
# https://www.ycombinator.com/companies/hatchet-2
# https://www.ycombinator.com/companies/sparechange
# https://www.ycombinator.com/companies/resonance
# https://www.ycombinator.com/companies/aether-energy
# https://www.ycombinator.com/companies/intercept
# https://www.ycombinator.com/companies/creo
# https://www.ycombinator.com/companies/celest
# https://www.ycombinator.com/companies/meticulate
# https://www.ycombinator.com/companies/patchwork
# https://www.ycombinator.com/companies/basalt-tech
# https://www.ycombinator.com/companies/tile
# https://www.ycombinator.com/companies/maihem
# https://www.ycombinator.com/companies/happenstance
# https://www.ycombinator.com/companies/stitch-technologies
# https://www.ycombinator.com/companies/healthtech-1
# https://www.ycombinator.com/companies/catx
# https://www.ycombinator.com/companies/chequpi
# https://www.ycombinator.com/companies/sante
# https://www.ycombinator.com/companies/silimate
# https://www.ycombinator.com/companies/prodtrace
# https://www.ycombinator.com/companies/chatter
# https://www.ycombinator.com/companies/trench
# https://www.ycombinator.com/companies/guac
# https://www.ycombinator.com/companies/fortuna-health
# https://www.ycombinator.com/companies/medisearch
# https://www.ycombinator.com/companies/unhaze
# https://www.ycombinator.com/companies/decoda-health
# https://www.ycombinator.com/companies/telophase
# https://www.ycombinator.com/companies/shasta-health
# https://www.ycombinator.com/companies/outset
# https://www.ycombinator.com/companies/kite
# https://www.ycombinator.com/companies/venta
# https://www.ycombinator.com/companies/datashare
# https://www.ycombinator.com/companies/talc
# https://www.ycombinator.com/companies/electric-air-previously-helios-climate
# https://www.ycombinator.com/companies/atla
# https://www.ycombinator.com/companies/sohar-health
# https://www.ycombinator.com/companies/accend
# https://www.ycombinator.com/companies/twenty
# https://www.ycombinator.com/companies/artie
# https://www.ycombinator.com/companies/theya
# https://www.ycombinator.com/companies/type
# https://www.ycombinator.com/companies/metal
# https://www.ycombinator.com/companies/adventris-pharmaceuticals
# https://www.ycombinator.com/companies/clearspace
# https://www.ycombinator.com/companies/coldreach
# https://www.ycombinator.com/companies/echo
# https://www.ycombinator.com/companies/hona
# https://www.ycombinator.com/companies/extend
# https://www.ycombinator.com/companies/chart
# https://www.ycombinator.com/companies/zenfetch
# https://www.ycombinator.com/companies/omnistrate
# https://www.ycombinator.com/companies/feather-3
# https://www.ycombinator.com/companies/latent
# https://www.ycombinator.com/companies/depot
# https://www.ycombinator.com/companies/struct
# https://www.ycombinator.com/companies/laminate
# https://www.ycombinator.com/companies/alphawatch-ai
# https://www.ycombinator.com/companies/cone
# https://www.ycombinator.com/companies/lancey
# https://www.ycombinator.com/companies/entvin
# https://www.ycombinator.com/companies/autone
# https://www.ycombinator.com/companies/hero
# https://www.ycombinator.com/companies/relate
# https://www.ycombinator.com/companies/trendex-own-the-stars
# https://www.ycombinator.com/companies/anchor
# https://www.ycombinator.com/companies/airhart-aeronautics
# https://www.ycombinator.com/companies/shipmates
# https://www.ycombinator.com/companies/thera
# https://www.ycombinator.com/companies/newscatcher
# https://www.ycombinator.com/companies/malama-health
# https://www.ycombinator.com/companies/seaflight-technologies
# https://www.ycombinator.com/companies/overwatch
# https://www.ycombinator.com/companies/tranch
# https://www.ycombinator.com/companies/ethosx
# https://www.ycombinator.com/companies/fetii
# https://www.ycombinator.com/companies/paces
# https://www.ycombinator.com/companies/silkchart
# https://www.ycombinator.com/companies/simplehash
# https://www.ycombinator.com/companies/anja-health
# https://www.ycombinator.com/companies/rthm
# https://www.ycombinator.com/companies/float-health
# https://www.ycombinator.com/companies/shaped
# https://www.ycombinator.com/companies/attain
# https://www.ycombinator.com/companies/trueplace
# https://www.ycombinator.com/companies/bracket
# https://www.ycombinator.com/companies/andson-biotech
# https://www.ycombinator.com/companies/theneo
# https://www.ycombinator.com/companies/telematica
# https://www.ycombinator.com/companies/smarthelio
# https://www.ycombinator.com/companies/cera
# https://www.ycombinator.com/companies/velt
# https://www.ycombinator.com/companies/tuva-health
# https://www.ycombinator.com/companies/salt
# https://www.ycombinator.com/companies/aeoncharge
# https://www.ycombinator.com/companies/dart
# https://www.ycombinator.com/companies/lightmeter
# https://www.ycombinator.com/companies/cutr
# https://www.ycombinator.com/companies/vance
# https://www.ycombinator.com/companies/onyx-private
# https://www.ycombinator.com/companies/teamout
# https://www.ycombinator.com/companies/samos-insurance
# https://www.ycombinator.com/companies/flightcontrol
# https://www.ycombinator.com/companies/syrona-health
# https://www.ycombinator.com/companies/mederva-health
# https://www.ycombinator.com/companies/spot-health
# https://www.ycombinator.com/companies/aklimate
# https://www.ycombinator.com/companies/nash
# https://www.ycombinator.com/companies/equipt-health
# https://www.ycombinator.com/companies/turion-space
# https://www.ycombinator.com/companies/cafe
# https://www.ycombinator.com/companies/bytebot
# https://www.ycombinator.com/companies/sfa-therapeutics-inc
# https://www.ycombinator.com/companies/crew
# https://www.ycombinator.com/companies/therify
# https://www.ycombinator.com/companies/byte-kitchen
# https://www.ycombinator.com/companies/abhi
# https://www.ycombinator.com/companies/ruth-health
# https://www.ycombinator.com/companies/mach9
# https://www.ycombinator.com/companies/heycharge
# https://www.ycombinator.com/companies/formance
# https://www.ycombinator.com/companies/scratch-data
# https://www.ycombinator.com/companies/cero
# https://www.ycombinator.com/companies/onestopkitchen
# https://www.ycombinator.com/companies/metlo
# https://www.ycombinator.com/companies/strive-math
# https://www.ycombinator.com/companies/ananya-health
# https://www.ycombinator.com/companies/archbee
# https://www.ycombinator.com/companies/inversion-space
# https://www.ycombinator.com/companies/promakhos-therapeutics
# https://www.ycombinator.com/companies/elto
# https://www.ycombinator.com/companies/cache
# https://www.ycombinator.com/companies/hera
# https://www.ycombinator.com/companies/comet-health
# https://www.ycombinator.com/companies/ruta-health
# https://www.ycombinator.com/companies/zepto
# https://www.ycombinator.com/companies/redcliffe-lifetech
# https://www.ycombinator.com/companies/stoke-space
# https://www.ycombinator.com/companies/treinta
# https://www.ycombinator.com/companies/eqtble
# https://www.ycombinator.com/companies/tackle
# https://www.ycombinator.com/companies/reshape-biotech
# https://www.ycombinator.com/companies/cheqout
# https://www.ycombinator.com/companies/estoca
# https://www.ycombinator.com/companies/machine26
# https://www.ycombinator.com/companies/dataherald
# https://www.ycombinator.com/companies/chatwoot
# https://www.ycombinator.com/companies/haystack
# https://www.ycombinator.com/companies/launcher-labs
# https://www.ycombinator.com/companies/sturdy-finance
# https://www.ycombinator.com/companies/dyte
# https://www.ycombinator.com/companies/veera-health
# https://www.ycombinator.com/companies/purpose-finance
# https://www.ycombinator.com/companies/fathom
# https://www.ycombinator.com/companies/care-weather
# https://www.ycombinator.com/companies/quadrant-health
# https://www.ycombinator.com/companies/gradia-health
# https://www.ycombinator.com/companies/pragmatic-leaders-ankai-inc
# https://www.ycombinator.com/companies/pesto
# https://www.ycombinator.com/companies/smartcuts
# https://www.ycombinator.com/companies/hapi
# https://www.ycombinator.com/companies/authzed
# https://www.ycombinator.com/companies/the-third-place
# https://www.ycombinator.com/companies/atrato
# https://www.ycombinator.com/companies/inbalance
# https://www.ycombinator.com/companies/techbiz
# https://www.ycombinator.com/companies/bueno-finance
# https://www.ycombinator.com/companies/slashauth
# https://www.ycombinator.com/companies/atob
# https://www.ycombinator.com/companies/gilgamesh-pharmaceuticals
# https://www.ycombinator.com/companies/matter
# https://www.ycombinator.com/companies/flat
# https://www.ycombinator.com/companies/byte
# https://www.ycombinator.com/companies/here
# https://www.ycombinator.com/companies/arketa
# https://www.ycombinator.com/companies/henry
# https://www.ycombinator.com/companies/hotplate
# https://www.ycombinator.com/companies/buildspace
# https://www.ycombinator.com/companies/atomic
# https://www.ycombinator.com/companies/zitara-technologies-inc
# https://www.ycombinator.com/companies/together-video-chat
# https://www.ycombinator.com/companies/cohere
# https://www.ycombinator.com/companies/clew
# https://www.ycombinator.com/companies/gather
# https://www.ycombinator.com/companies/bento
# https://www.ycombinator.com/companies/racer
# https://www.ycombinator.com/companies/whatnot
# https://www.ycombinator.com/companies/h1
# https://www.ycombinator.com/companies/tambua-health
# https://www.ycombinator.com/companies/atmo
# https://www.ycombinator.com/companies/guruhotel
# https://www.ycombinator.com/companies/hent
# https://www.ycombinator.com/companies/breathe-well-being
# https://www.ycombinator.com/companies/farmtheory
# https://www.ycombinator.com/companies/fella-health
# https://www.ycombinator.com/companies/altay-therapeutics
# https://www.ycombinator.com/companies/edlyft
# https://www.ycombinator.com/companies/replicate
# https://www.ycombinator.com/companies/acho
# https://www.ycombinator.com/companies/deep-meditate
# https://www.ycombinator.com/companies/kaiten
# https://www.ycombinator.com/companies/synapsica-healthcare
# https://www.ycombinator.com/companies/pantheon
# https://www.ycombinator.com/companies/hideout
# https://www.ycombinator.com/companies/datree
# https://www.ycombinator.com/companies/gather-2
# https://www.ycombinator.com/companies/hightouch
# https://www.ycombinator.com/companies/epic-aerospace
# https://www.ycombinator.com/companies/aspect
# https://www.ycombinator.com/companies/traces
# https://www.ycombinator.com/companies/heru
# https://www.ycombinator.com/companies/hatchways
# https://www.ycombinator.com/companies/mindset-health
# https://www.ycombinator.com/companies/shift-health
# https://www.ycombinator.com/companies/mighty-health
# https://www.ycombinator.com/companies/safely-finance
# https://www.ycombinator.com/companies/path
# https://www.ycombinator.com/companies/shef
# https://www.ycombinator.com/companies/endpoint-health
# https://www.ycombinator.com/companies/latchel
# https://www.ycombinator.com/companies/edyst
# https://www.ycombinator.com/companies/intact-therapeutics
# https://www.ycombinator.com/companies/okteto
# https://www.ycombinator.com/companies/atomic-alchemy
# https://www.ycombinator.com/companies/viosera-therapeutics
# https://www.ycombinator.com/companies/ai-insurance
# https://www.ycombinator.com/companies/weathercheck
# https://www.ycombinator.com/companies/avalanche
# https://www.ycombinator.com/companies/hatch
# https://www.ycombinator.com/companies/ascen
# https://www.ycombinator.com/companies/catch
# https://www.ycombinator.com/companies/union-apartment
# https://www.ycombinator.com/companies/cherry
# https://www.ycombinator.com/companies/chaser
# https://www.ycombinator.com/companies/green-energy-exchange
# https://www.ycombinator.com/companies/aesthetic
# https://www.ycombinator.com/companies/dorian-therapeutics
# https://www.ycombinator.com/companies/spate
# https://www.ycombinator.com/companies/dreamcraft-entertainment-inc
# https://www.ycombinator.com/companies/purple-plate
# https://www.ycombinator.com/companies/hepatx
# https://www.ycombinator.com/companies/satchel
# https://www.ycombinator.com/companies/the-buttermilk-company
# https://www.ycombinator.com/companies/synthetic-minds
# https://www.ycombinator.com/companies/newfront-insurance
# https://www.ycombinator.com/companies/memora-health
# https://www.ycombinator.com/companies/torch
# https://www.ycombinator.com/companies/aesculatech
# https://www.ycombinator.com/companies/mayhem
# https://www.ycombinator.com/companies/lambda-tea
# https://www.ycombinator.com/companies/hexel
# https://www.ycombinator.com/companies/vathys
# https://www.ycombinator.com/companies/tipe
# https://www.ycombinator.com/companies/necto
# https://www.ycombinator.com/companies/long-term-stock-exchange
# https://www.ycombinator.com/companies/thematic
# https://www.ycombinator.com/companies/flowspace
# https://www.ycombinator.com/companies/rabbet
# https://www.ycombinator.com/companies/pathrise
# https://www.ycombinator.com/companies/surematics
# https://www.ycombinator.com/companies/plasticity
# https://www.ycombinator.com/companies/feather
# https://www.ycombinator.com/companies/social-construct
# https://www.ycombinator.com/companies/covetly
# https://www.ycombinator.com/companies/aclu
# https://www.ycombinator.com/companies/extern
# https://www.ycombinator.com/companies/sinovia-technologies
# https://www.ycombinator.com/companies/tizeti
# https://www.ycombinator.com/companies/tetra
# https://www.ycombinator.com/companies/arthena
# https://www.ycombinator.com/companies/volt-health
# https://www.ycombinator.com/companies/entry
# https://www.ycombinator.com/companies/lithit
# https://www.ycombinator.com/companies/next-tech
# https://www.ycombinator.com/companies/tickle
# https://www.ycombinator.com/companies/trinket
# https://www.ycombinator.com/companies/teachme
# https://www.ycombinator.com/companies/mathchat
# https://www.ycombinator.com/companies/blendspace
# https://www.ycombinator.com/companies/athelas
# https://www.ycombinator.com/companies/the-athletic
# https://www.ycombinator.com/companies/smartpath
# https://www.ycombinator.com/companies/garten
# https://www.ycombinator.com/companies/saleswhale
# https://www.ycombinator.com/companies/techmate
# https://www.ycombinator.com/companies/emote
# https://www.ycombinator.com/companies/haywheel
# https://www.ycombinator.com/companies/metapacket
# https://www.ycombinator.com/companies/sway-finance
# https://www.ycombinator.com/companies/patientbank
# https://www.ycombinator.com/companies/relativity-space
# https://www.ycombinator.com/companies/inevitable-tech
# https://www.ycombinator.com/companies/chatfuel
# https://www.ycombinator.com/companies/amberbox-gunshot-detection
# https://www.ycombinator.com/companies/trac
# https://www.ycombinator.com/companies/patchwork-security
# https://www.ycombinator.com/companies/ottimate
# https://www.ycombinator.com/companies/the-ticket-fairy
# https://www.ycombinator.com/companies/her
# https://www.ycombinator.com/companies/picktrace
# https://www.ycombinator.com/companies/thrive-agritech
# https://www.ycombinator.com/companies/leaders-in-tech
# https://www.ycombinator.com/companies/teabot
# https://www.ycombinator.com/companies/cloudstitch
# https://www.ycombinator.com/companies/fetch
# https://www.ycombinator.com/companies/locent
# https://www.ycombinator.com/companies/stitch-health
# https://www.ycombinator.com/companies/lucira-health
# https://www.ycombinator.com/companies/equipmentshare
# https://www.ycombinator.com/companies/makrwatch
# https://www.ycombinator.com/companies/chariot
# https://www.ycombinator.com/companies/raven-tech
# https://www.ycombinator.com/companies/yhat
# https://www.ycombinator.com/companies/vest
# https://www.ycombinator.com/companies/paperspace
# https://www.ycombinator.com/companies/pachyderm
# https://www.ycombinator.com/companies/direct-match
# https://www.ycombinator.com/companies/checkr
# https://www.ycombinator.com/companies/picnichealth
# https://www.ycombinator.com/companies/hive
# https://www.ycombinator.com/companies/alchemy
# https://www.ycombinator.com/companies/tule
# https://www.ycombinator.com/companies/kash
# https://www.ycombinator.com/companies/hauteday
# https://www.ycombinator.com/companies/cheddar
# https://www.ycombinator.com/companies/naytev
# https://www.ycombinator.com/companies/dyspatch
# https://www.ycombinator.com/companies/theorem
# https://www.ycombinator.com/companies/noora-health
# https://www.ycombinator.com/companies/zesty
# https://www.ycombinator.com/companies/sketchdeck
# https://www.ycombinator.com/companies/hoverchat
# https://www.ycombinator.com/companies/asseta
# https://www.ycombinator.com/companies/hackermeter
# https://www.ycombinator.com/companies/bloomthat
# https://www.ycombinator.com/companies/watchsend
# https://www.ycombinator.com/companies/meta
# https://www.ycombinator.com/companies/stackmachine
# https://www.ycombinator.com/companies/heap
# https://www.ycombinator.com/companies/etleap
# https://www.ycombinator.com/companies/cheetah
# https://www.ycombinator.com/companies/padlet
# https://www.ycombinator.com/companies/medxt
# https://www.ycombinator.com/companies/flightcar
# https://www.ycombinator.com/companies/natero
# https://www.ycombinator.com/companies/pixate
# https://www.ycombinator.com/companies/thread
# https://www.ycombinator.com/companies/hipset
# https://www.ycombinator.com/companies/airshared
# https://www.ycombinator.com/companies/arc
# https://www.ycombinator.com/companies/hireart
# https://www.ycombinator.com/companies/yourmechanic
# https://www.ycombinator.com/companies/authy
# https://www.ycombinator.com/companies/chute
# https://www.ycombinator.com/companies/brace
# https://www.ycombinator.com/companies/jellyfish-art
# https://www.ycombinator.com/companies/hackerrank
# https://www.ycombinator.com/companies/science-exchange
# https://www.ycombinator.com/companies/clutch
# https://www.ycombinator.com/companies/automatic
# https://www.ycombinator.com/companies/interstate
# https://www.ycombinator.com/companies/zerocater
# https://www.ycombinator.com/companies/chartio
# https://www.ycombinator.com/companies/gantto
# https://www.ycombinator.com/companies/etacts
# https://www.ycombinator.com/companies/cue
# https://www.ycombinator.com/companies/launchhear
# https://www.ycombinator.com/companies/flightcaster
# https://www.ycombinator.com/companies/wakemate
# https://www.ycombinator.com/companies/plurchase
# https://www.ycombinator.com/companies/fanchatter
# https://www.ycombinator.com/companies/ticket-stumbler
# https://www.ycombinator.com/companies/precognate
# https://www.ycombinator.com/companies/job-alchemist
# https://www.ycombinator.com/companies/machine-zone
# https://www.ycombinator.com/companies/appjet
# https://www.ycombinator.com/companies/contestmachine
# https://www.ycombinator.com/companies/twitch
# https://www.ycombinator.com/companies/auctomatic
# https://www.ycombinator.com/companies/jumpchat
# Company URLs added to company data and saved successfully.
# Company names for which URLs are not updated: []

# %% [markdown]
# update the structure of the JSON file so that the "url" is placed directly above the "Name" in each company's entry

# %%
import json

# Load the JSON data
with open('company_data.json', 'r') as file:
    data = json.load(file)

if data is not None:  # Check if data is not None
    # Rename the "url" key to "yc-company url" if it exists and move it to the first position
    for company in data:
        # Check if the company dictionary is not None
        if company is not None:
            if company.get('url') is not None:
                company['yc-company url'] = company.pop('url')

    # Update the structure
    for company in data:
        # Check if the company dictionary is not None
        if company is not None:
            # Get the "yc-company url" value
            url = company.pop('yc-company url', None)  # Handle the case if 'yc-company url' doesn't exist
            # Reconstruct the dictionary with reordered keys
            updated_company = {}
            if url is not None:
                updated_company['yc-company url'] = url
            for key, value in company.items():
                updated_company[key] = value
            # Update the original dictionary with the reordered keys
            company.clear()
            company.update(updated_company)

    # Save the updated JSON data
    with open('updated_company_data.json', 'w') as file:
        json.dump(data, file, indent=4)

    # Print the structure of the first few dictionaries after updating
    for i, company in enumerate(data[:5], start=1):
        print(f"Company {i}:")
        print(json.dumps(company, indent=4))
        print()
else:
    print("No data loaded from the JSON file.")
# Out:
# Company 1:
# {
#     "yc-company url": "https://www.ycombinator.com/companies/trueclaim",
#     "Name": "TrueClaim",
#     "Tagline": "Automatically saving self-insured companies 7% on healthcare",
#     "Description": "TrueClaim processes all payments between healthcare providers and companies that self-fund their insurance. Unlike incumbents, TrueClaim uses newly available data and AI to save companies 7% of their healthcare costs.",
#     "Batch": "W24",
#     "Company Type": "Active",
#     "Industry Tags": null,
#     "Location": "Location:San Francisco",
#     "Website URL": "https://www.trytrueclaim.com",
#     "Year Founded": "Founded:2023",
#     "Team Size": "Team Size:2",
#     "LinkedIn Profile": "https://linkedin.com/in/rwbayer",
#     "Founders": [
#         {
#             "Name": "Barbora Howell",
#             "Role": null,
#             "Biography": "Barbora got her MBA at Stanford. She joined Hinge Health as employee #30 where she built and ran a number of functions, including HR, benefits and customer billing. After scaling Hinge Health to >700 employees and hundreds of customers, Barbora ran clinical operations at Pine Park Health - a primary care provider for residents of assisted living facilities and a YC company - where she served on the executive team and was in charge of member support, care coordination and more.",
#             "LinkedIn Profile": "https://linkedin.com/in/podzimkovab"
#         },
#         {
#             "Name": "Bobby Bayer",
#             "Role": null,
#             "Biography": "Co-founder and CTO of TrueClaim (W24). Previously, Bobby spent 7 years as Senior Software Engineer building and scaling health tech solutions at pMD. He established and grew pMD\u2019s RCM software and services divisions as Software Engineering Manager. Prior to that, he launched patient engagement software as a Senior Software Engineer. 30% of the revenue growth at pMD during his tenure could be directly attributed to a product that he launched.",
#             "LinkedIn Profile": "https://linkedin.com/in/rwbayer"
#         }
#     ]
# }
#
# Company 2:
# {
#     "yc-company url": "https://www.ycombinator.com/companies/cocrafter",
#     "Name": "CoCrafter",
#     "Tagline": "B2B construction marketplace to match contractors and subcontractors.",
#     "Description": "CoCrafter is a construction marketplace to match contractors and subcontractors. Starting in the strong German SMB sector, CoCrafter helps contractors to find and manage local as well as foreign subcontractors.",
#     "Batch": "W24",
#     "Company Type": "Active",
#     "Industry Tags": null,
#     "Location": "Location:Munich, Germany",
#     "Website URL": "https://cocrafter.com/",
#     "Year Founded": "Founded:2023",
#     "Team Size": "Team Size:3",
#     "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227",
#     "Founders": [
#         {
#             "Name": "Johannes Lutz",
#             "Role": null,
#             "Biography": "Building CoCrafter. Previously built Innovis VC, Europe's largest VC student association. Passionate about tennis & piano.",
#             "LinkedIn Profile": "https://linkedin.com/in/johanneslutz"
#         },
#         {
#             "Name": "Philipp Rollwage",
#             "Role": null,
#             "Biography": "Building CoCrafter to empower the long-tail construction industry in Europe. Previously built Innovis VC, Europe's largest student VC initiative. In Love with easy-to-use software products. Hobby barista and ambitious triathlete.",
#             "LinkedIn Profile": "https://linkedin.com/in/philipp-rollwage"
#         },
#         {
#             "Name": "Annabell V.",
#             "Role": null,
#             "Biography": "Building CoCrafter - a construction marketplace matching contractors with subcontractors across Europe. Passionate about building products that create value & users love.",
#             "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227"
#         }
#     ]
# }
#
# Company 3:
# {
#     "yc-company url": "https://www.ycombinator.com/companies/reform",
#     "Name": "Reform",
#     "Tagline": "Retool for logistics companies",
#     "Description": "Reform makes it easy for logistics companies to build internal automation tools. We're like Retool built specifically for logistics software. Our customers use Reform to build internal tools that can automate tasks such as customs clearance filing, shipment processing, and customer onboarding.",
#     "Batch": "W24",
#     "Company Type": "Active",
#     "Industry Tags": null,
#     "Location": "Location:San Francisco",
#     "Website URL": "https://www.reformhq.com",
#     "Year Founded": "Founded:2023",
#     "Team Size": "Team Size:3",
#     "LinkedIn Profile": "https://linkedin.com/in/pradhit",
#     "Twitter Handle": "https://twitter.com/abuhasho",
#     "Founders": [
#         {
#             "Name": "Saif Abuhashish",
#             "Role": null,
#             "Biography": "Saif is the co-founder and CEO of Reform. Prior to Reform, Saif was part of a 7 person team at Amazon responsible for building their worldwide robotics firmware. He was also tech lead at Drift where he built the foundations of their partnerships and integrations suite. Before that, he was engineer #1 on Capital One's conversational AI team and helped scale their product to millions of MAUs. Saif received his BS in Computer Engineering and Mathematics from Northeastern University.",
#             "LinkedIn Profile": "https://linkedin.com/in/saifabuhashish"
#         },
#         {
#             "Name": "Omar Abuhashish",
#             "Role": null,
#             "Biography": "Omar is the co-founder and president at Reform. He holds a BS in CS and mechanical & aerospace engineering from NYU. Prior to Reform, Omar led the inception of CoinTracker\u2019s (YC W18) new products team and focused on the research and implementation of 0 \u2192 1 products, including enterprise accounting. Prior to that, he was engineer #1 at Altan Insights where he built the industry-leading fractional asset investing platform.",
#             "Twitter Profile": "https://twitter.com/abuhasho",
#             "LinkedIn Profile": "https://linkedin.com/in/omarabuhashish"
#         },
#         {
#             "Name": "Pradhit Gosula",
#             "Role": null,
#             "Biography": "Pradhit is co-founder and CTO of Reform. Previously he was an early engineer at CoinTracker (YC W18), building their tax engine from the ground up as well as 0 \u2192 1 products on their new products team. Before that, he was a software engineer at Microsoft building data pipelines to process petabytes of telemetry from Azure build systems.",
#             "LinkedIn Profile": "https://linkedin.com/in/pradhit"
#         }
#     ]
# }
#
# Company 4:
# {
#     "yc-company url": "https://www.ycombinator.com/companies/piramidal",
#     "Name": "Piramidal",
#     "Tagline": "Foundation Model for the Brain",
#     "Description": "Get instant diagnosis for the vast majority of neurological conditions using our Foundational AI.",
#     "Batch": "W24",
#     "Company Type": "Active",
#     "Industry Tags": null,
#     "Location": "Location:San Francisco",
#     "Website URL": "https://piramidal.ai",
#     "Year Founded": "Founded:2024",
#     "Team Size": "Team Size:2",
#     "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b",
#     "Twitter Handle": "https://twitter.com/dsacellarius",
#     "Founders": [
#         {
#             "Name": "Dimitris Fotis Sakellariou",
#             "Role": null,
#             "Biography": "Founder and CEO at Piramidal. Spent four years at IQVIA shipping foundational AI code to production scaled for pharma and healthcare clients. Have conducted EEG research for 12 years, authored peer reviewed publications, spent more than four years in research hospitals conducting long-term EEG recordings, reviewing EEG recordings with expert epileptologists, participated in brain surgeries, and built capability around the brain. King's College London alum.",
#             "Twitter Profile": "https://twitter.com/dsacellarius",
#             "LinkedIn Profile": "https://linkedin.com/in/sacellarius"
#         },
#         {
#             "Name": "Kris Pahuja",
#             "Role": null,
#             "Biography": "co-founder and all things product and business @piramidal.\npreviously product lead at google & spotify for ai and healthcare.\nco-founded gyftgo and scaled to $1m arr.\nAt google, owned chrome os monetization from $0 to $300m arr.",
#             "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b"
#         }
#     ]
# }
#
# Company 5:
# {
#     "yc-company url": "https://www.ycombinator.com/companies/junction-bioscience",
#     "Name": "Junction Bioscience",
#     "Tagline": "AI Hypothesis Engine for Molecular Discovery",
#     "Description": "Junction Bioscience is building an autonomous AI scientist to navigate the discovery of transformative medicines. Our scientific hypothesis engine iterates upon breakthrough chemistry from the laboratory to achieve clarity and control over the molecular basis of disease. We focus on the intersection of neuroinflammation and immunology where uncommon molecular insights position us to develop best-in-class therapies for millions of patients in need.",
#     "Batch": "W24",
#     "Company Type": "Active",
#     "Industry Tags": null,
#     "Location": "Location:San Francisco",
#     "Website URL": "https://www.junction.bio/",
#     "Year Founded": "Founded:2024",
#     "Team Size": "Team Size:1",
#     "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680",
#     "Founders": [
#         {
#             "Name": "Brian Petkov",
#             "Role": null,
#             "Biography": "Brian is a theoretical physicist and drug hunter with degrees in mathematics and chemistry from Duke University and doctoral training from NYU. He was previously the first employee and Vice President at a computational drug design startup where he led the Machine Learning operation and grew a 30-person team to success on previously-undruggable targets.",
#             "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680"
#         }
#     ]
# }

# %%
import json
from unidecode import unidecode

# Function to fix Unicode errors and remove escape sequences in JSON data
def fix_unicode_and_remove_escapes(data):
    if isinstance(data, str):
        # Transliterate Unicode characters into ASCII
        data = unidecode(data)
        # Remove escape sequences
        data = data.replace('\n', '').replace('\t', '').replace('\\u', '')
        return data
    elif isinstance(data, dict):
        return {fix_unicode_and_remove_escapes(key): fix_unicode_and_remove_escapes(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [fix_unicode_and_remove_escapes(item) for item in data]
    else:
        return data

# Read the original JSON file
with open('updated_company_data.json', 'r', encoding='utf-8') as file:
    try:
        # Load JSON data
        original_data = json.load(file)
    except UnicodeDecodeError:
        # If Unicode error occurs, read the file as bytes and decode it
        file.seek(0)
        original_data = json.loads(file.read().decode('utf-8'))

# Fix Unicode errors and remove escape sequences in original JSON data
fixed_data = fix_unicode_and_remove_escapes(original_data)

# Write the fixed JSON data back to the file
with open('updated_company_data.json', 'w', encoding='utf-8') as file:
    json.dump(fixed_data, file, ensure_ascii=False, indent=4)

# Function to print the first few elements of JSON data
def print_first_few_elements(data, num_elements=5):
    print(json.dumps(data[:num_elements], indent=4))


# Print the first few elements of fixed JSON data
print("\nFixed JSON data (First 5 elements):")
print_first_few_elements(fixed_data)
# Out:
# Fixed JSON data (First 5 elements):
# [
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/trueclaim",
#         "Name": "TrueClaim",
#         "Tagline": "Automatically saving self-insured companies 7% on healthcare",
#         "Description": "TrueClaim processes all payments between healthcare providers and companies that self-fund their insurance. Unlike incumbents, TrueClaim uses newly available data and AI to save companies 7% of their healthcare costs.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.trytrueclaim.com",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:2",
#         "LinkedIn Profile": "https://linkedin.com/in/rwbayer",
#         "Founders": [
#             {
#                 "Name": "Barbora Howell",
#                 "Role": null,
#                 "Biography": "Barbora got her MBA at Stanford. She joined Hinge Health as employee #30 where she built and ran a number of functions, including HR, benefits and customer billing. After scaling Hinge Health to >700 employees and hundreds of customers, Barbora ran clinical operations at Pine Park Health - a primary care provider for residents of assisted living facilities and a YC company - where she served on the executive team and was in charge of member support, care coordination and more.",
#                 "LinkedIn Profile": "https://linkedin.com/in/podzimkovab"
#             },
#             {
#                 "Name": "Bobby Bayer",
#                 "Role": null,
#                 "Biography": "Co-founder and CTO of TrueClaim (W24). Previously, Bobby spent 7 years as Senior Software Engineer building and scaling health tech solutions at pMD. He established and grew pMD's RCM software and services divisions as Software Engineering Manager. Prior to that, he launched patient engagement software as a Senior Software Engineer. 30% of the revenue growth at pMD during his tenure could be directly attributed to a product that he launched.",
#                 "LinkedIn Profile": "https://linkedin.com/in/rwbayer"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/cocrafter",
#         "Name": "CoCrafter",
#         "Tagline": "B2B construction marketplace to match contractors and subcontractors.",
#         "Description": "CoCrafter is a construction marketplace to match contractors and subcontractors. Starting in the strong German SMB sector, CoCrafter helps contractors to find and manage local as well as foreign subcontractors.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:Munich, Germany",
#         "Website URL": "https://cocrafter.com/",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:3",
#         "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227",
#         "Founders": [
#             {
#                 "Name": "Johannes Lutz",
#                 "Role": null,
#                 "Biography": "Building CoCrafter. Previously built Innovis VC, Europe's largest VC student association. Passionate about tennis & piano.",
#                 "LinkedIn Profile": "https://linkedin.com/in/johanneslutz"
#             },
#             {
#                 "Name": "Philipp Rollwage",
#                 "Role": null,
#                 "Biography": "Building CoCrafter to empower the long-tail construction industry in Europe. Previously built Innovis VC, Europe's largest student VC initiative. In Love with easy-to-use software products. Hobby barista and ambitious triathlete.",
#                 "LinkedIn Profile": "https://linkedin.com/in/philipp-rollwage"
#             },
#             {
#                 "Name": "Annabell V.",
#                 "Role": null,
#                 "Biography": "Building CoCrafter - a construction marketplace matching contractors with subcontractors across Europe. Passionate about building products that create value & users love.",
#                 "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/reform",
#         "Name": "Reform",
#         "Tagline": "Retool for logistics companies",
#         "Description": "Reform makes it easy for logistics companies to build internal automation tools. We're like Retool built specifically for logistics software. Our customers use Reform to build internal tools that can automate tasks such as customs clearance filing, shipment processing, and customer onboarding.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.reformhq.com",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:3",
#         "LinkedIn Profile": "https://linkedin.com/in/pradhit",
#         "Twitter Handle": "https://twitter.com/abuhasho",
#         "Founders": [
#             {
#                 "Name": "Saif Abuhashish",
#                 "Role": null,
#                 "Biography": "Saif is the co-founder and CEO of Reform. Prior to Reform, Saif was part of a 7 person team at Amazon responsible for building their worldwide robotics firmware. He was also tech lead at Drift where he built the foundations of their partnerships and integrations suite. Before that, he was engineer #1 on Capital One's conversational AI team and helped scale their product to millions of MAUs. Saif received his BS in Computer Engineering and Mathematics from Northeastern University.",
#                 "LinkedIn Profile": "https://linkedin.com/in/saifabuhashish"
#             },
#             {
#                 "Name": "Omar Abuhashish",
#                 "Role": null,
#                 "Biography": "Omar is the co-founder and president at Reform. He holds a BS in CS and mechanical & aerospace engineering from NYU. Prior to Reform, Omar led the inception of CoinTracker's (YC W18) new products team and focused on the research and implementation of 0 - 1 products, including enterprise accounting. Prior to that, he was engineer #1 at Altan Insights where he built the industry-leading fractional asset investing platform.",
#                 "Twitter Profile": "https://twitter.com/abuhasho",
#                 "LinkedIn Profile": "https://linkedin.com/in/omarabuhashish"
#             },
#             {
#                 "Name": "Pradhit Gosula",
#                 "Role": null,
#                 "Biography": "Pradhit is co-founder and CTO of Reform. Previously he was an early engineer at CoinTracker (YC W18), building their tax engine from the ground up as well as 0 - 1 products on their new products team. Before that, he was a software engineer at Microsoft building data pipelines to process petabytes of telemetry from Azure build systems.",
#                 "LinkedIn Profile": "https://linkedin.com/in/pradhit"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/piramidal",
#         "Name": "Piramidal",
#         "Tagline": "Foundation Model for the Brain",
#         "Description": "Get instant diagnosis for the vast majority of neurological conditions using our Foundational AI.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://piramidal.ai",
#         "Year Founded": "Founded:2024",
#         "Team Size": "Team Size:2",
#         "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b",
#         "Twitter Handle": "https://twitter.com/dsacellarius",
#         "Founders": [
#             {
#                 "Name": "Dimitris Fotis Sakellariou",
#                 "Role": null,
#                 "Biography": "Founder and CEO at Piramidal. Spent four years at IQVIA shipping foundational AI code to production scaled for pharma and healthcare clients. Have conducted EEG research for 12 years, authored peer reviewed publications, spent more than four years in research hospitals conducting long-term EEG recordings, reviewing EEG recordings with expert epileptologists, participated in brain surgeries, and built capability around the brain. King's College London alum.",
#                 "Twitter Profile": "https://twitter.com/dsacellarius",
#                 "LinkedIn Profile": "https://linkedin.com/in/sacellarius"
#             },
#             {
#                 "Name": "Kris Pahuja",
#                 "Role": null,
#                 "Biography": "co-founder and all things product and business @piramidal.previously product lead at google & spotify for ai and healthcare.co-founded gyftgo and scaled to $1m arr.At google, owned chrome os monetization from $0 to $300m arr.",
#                 "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/junction-bioscience",
#         "Name": "Junction Bioscience",
#         "Tagline": "AI Hypothesis Engine for Molecular Discovery",
#         "Description": "Junction Bioscience is building an autonomous AI scientist to navigate the discovery of transformative medicines. Our scientific hypothesis engine iterates upon breakthrough chemistry from the laboratory to achieve clarity and control over the molecular basis of disease. We focus on the intersection of neuroinflammation and immunology where uncommon molecular insights position us to develop best-in-class therapies for millions of patients in need.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.junction.bio/",
#         "Year Founded": "Founded:2024",
#         "Team Size": "Team Size:1",
#         "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680",
#         "Founders": [
#             {
#                 "Name": "Brian Petkov",
#                 "Role": null,
#                 "Biography": "Brian is a theoretical physicist and drug hunter with degrees in mathematics and chemistry from Duke University and doctoral training from NYU. He was previously the first employee and Vice President at a computational drug design startup where he led the Machine Learning operation and grew a 30-person team to success on previously-undruggable targets.",
#                 "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680"
#             }
#         ]
#     }
# ]

# %%
import json
from unidecode import unidecode

# Function to remove \r and \n from strings
def remove_newlines(data):
    if isinstance(data, str):
        return data.replace('\r', '').replace('\n', '')
    elif isinstance(data, dict):
        return {key: remove_newlines(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [remove_newlines(item) for item in data]
    else:
        return data

# Read the JSON file
with open('updated_company_data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Remove \r and \n from the data
updated_data = remove_newlines(data)

# Write the updated data back to the file
with open('updated_company_data.json', 'w', encoding='utf-8') as file:
    json.dump(updated_data, file, ensure_ascii=False, indent=4)

# Print the first 5 elements of the updated data
print("First 5 elements of updated JSON data (after removing \\r and \\n):")
print(json.dumps(updated_data[:5], indent=4))
# Out:
# First 5 elements of updated JSON data (after removing \r and \n):
# [
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/trueclaim",
#         "Name": "TrueClaim",
#         "Tagline": "Automatically saving self-insured companies 7% on healthcare",
#         "Description": "TrueClaim processes all payments between healthcare providers and companies that self-fund their insurance. Unlike incumbents, TrueClaim uses newly available data and AI to save companies 7% of their healthcare costs.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.trytrueclaim.com",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:2",
#         "LinkedIn Profile": "https://linkedin.com/in/rwbayer",
#         "Founders": [
#             {
#                 "Name": "Barbora Howell",
#                 "Role": null,
#                 "Biography": "Barbora got her MBA at Stanford. She joined Hinge Health as employee #30 where she built and ran a number of functions, including HR, benefits and customer billing. After scaling Hinge Health to >700 employees and hundreds of customers, Barbora ran clinical operations at Pine Park Health - a primary care provider for residents of assisted living facilities and a YC company - where she served on the executive team and was in charge of member support, care coordination and more.",
#                 "LinkedIn Profile": "https://linkedin.com/in/podzimkovab"
#             },
#             {
#                 "Name": "Bobby Bayer",
#                 "Role": null,
#                 "Biography": "Co-founder and CTO of TrueClaim (W24). Previously, Bobby spent 7 years as Senior Software Engineer building and scaling health tech solutions at pMD. He established and grew pMD's RCM software and services divisions as Software Engineering Manager. Prior to that, he launched patient engagement software as a Senior Software Engineer. 30% of the revenue growth at pMD during his tenure could be directly attributed to a product that he launched.",
#                 "LinkedIn Profile": "https://linkedin.com/in/rwbayer"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/cocrafter",
#         "Name": "CoCrafter",
#         "Tagline": "B2B construction marketplace to match contractors and subcontractors.",
#         "Description": "CoCrafter is a construction marketplace to match contractors and subcontractors. Starting in the strong German SMB sector, CoCrafter helps contractors to find and manage local as well as foreign subcontractors.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:Munich, Germany",
#         "Website URL": "https://cocrafter.com/",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:3",
#         "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227",
#         "Founders": [
#             {
#                 "Name": "Johannes Lutz",
#                 "Role": null,
#                 "Biography": "Building CoCrafter. Previously built Innovis VC, Europe's largest VC student association. Passionate about tennis & piano.",
#                 "LinkedIn Profile": "https://linkedin.com/in/johanneslutz"
#             },
#             {
#                 "Name": "Philipp Rollwage",
#                 "Role": null,
#                 "Biography": "Building CoCrafter to empower the long-tail construction industry in Europe. Previously built Innovis VC, Europe's largest student VC initiative. In Love with easy-to-use software products. Hobby barista and ambitious triathlete.",
#                 "LinkedIn Profile": "https://linkedin.com/in/philipp-rollwage"
#             },
#             {
#                 "Name": "Annabell V.",
#                 "Role": null,
#                 "Biography": "Building CoCrafter - a construction marketplace matching contractors with subcontractors across Europe. Passionate about building products that create value & users love.",
#                 "LinkedIn Profile": "https://www.linkedin.com/in/annabell-v-86a73b227"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/reform",
#         "Name": "Reform",
#         "Tagline": "Retool for logistics companies",
#         "Description": "Reform makes it easy for logistics companies to build internal automation tools. We're like Retool built specifically for logistics software. Our customers use Reform to build internal tools that can automate tasks such as customs clearance filing, shipment processing, and customer onboarding.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.reformhq.com",
#         "Year Founded": "Founded:2023",
#         "Team Size": "Team Size:3",
#         "LinkedIn Profile": "https://linkedin.com/in/pradhit",
#         "Twitter Handle": "https://twitter.com/abuhasho",
#         "Founders": [
#             {
#                 "Name": "Saif Abuhashish",
#                 "Role": null,
#                 "Biography": "Saif is the co-founder and CEO of Reform. Prior to Reform, Saif was part of a 7 person team at Amazon responsible for building their worldwide robotics firmware. He was also tech lead at Drift where he built the foundations of their partnerships and integrations suite. Before that, he was engineer #1 on Capital One's conversational AI team and helped scale their product to millions of MAUs. Saif received his BS in Computer Engineering and Mathematics from Northeastern University.",
#                 "LinkedIn Profile": "https://linkedin.com/in/saifabuhashish"
#             },
#             {
#                 "Name": "Omar Abuhashish",
#                 "Role": null,
#                 "Biography": "Omar is the co-founder and president at Reform. He holds a BS in CS and mechanical & aerospace engineering from NYU. Prior to Reform, Omar led the inception of CoinTracker's (YC W18) new products team and focused on the research and implementation of 0 - 1 products, including enterprise accounting. Prior to that, he was engineer #1 at Altan Insights where he built the industry-leading fractional asset investing platform.",
#                 "Twitter Profile": "https://twitter.com/abuhasho",
#                 "LinkedIn Profile": "https://linkedin.com/in/omarabuhashish"
#             },
#             {
#                 "Name": "Pradhit Gosula",
#                 "Role": null,
#                 "Biography": "Pradhit is co-founder and CTO of Reform. Previously he was an early engineer at CoinTracker (YC W18), building their tax engine from the ground up as well as 0 - 1 products on their new products team. Before that, he was a software engineer at Microsoft building data pipelines to process petabytes of telemetry from Azure build systems.",
#                 "LinkedIn Profile": "https://linkedin.com/in/pradhit"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/piramidal",
#         "Name": "Piramidal",
#         "Tagline": "Foundation Model for the Brain",
#         "Description": "Get instant diagnosis for the vast majority of neurological conditions using our Foundational AI.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://piramidal.ai",
#         "Year Founded": "Founded:2024",
#         "Team Size": "Team Size:2",
#         "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b",
#         "Twitter Handle": "https://twitter.com/dsacellarius",
#         "Founders": [
#             {
#                 "Name": "Dimitris Fotis Sakellariou",
#                 "Role": null,
#                 "Biography": "Founder and CEO at Piramidal. Spent four years at IQVIA shipping foundational AI code to production scaled for pharma and healthcare clients. Have conducted EEG research for 12 years, authored peer reviewed publications, spent more than four years in research hospitals conducting long-term EEG recordings, reviewing EEG recordings with expert epileptologists, participated in brain surgeries, and built capability around the brain. King's College London alum.",
#                 "Twitter Profile": "https://twitter.com/dsacellarius",
#                 "LinkedIn Profile": "https://linkedin.com/in/sacellarius"
#             },
#             {
#                 "Name": "Kris Pahuja",
#                 "Role": null,
#                 "Biography": "co-founder and all things product and business @piramidal.previously product lead at google & spotify for ai and healthcare.co-founded gyftgo and scaled to $1m arr.At google, owned chrome os monetization from $0 to $300m arr.",
#                 "LinkedIn Profile": "https://linkedin.com/in/kris-pahuja-a59a905b"
#             }
#         ]
#     },
#     {
#         "yc-company url": "https://www.ycombinator.com/companies/junction-bioscience",
#         "Name": "Junction Bioscience",
#         "Tagline": "AI Hypothesis Engine for Molecular Discovery",
#         "Description": "Junction Bioscience is building an autonomous AI scientist to navigate the discovery of transformative medicines. Our scientific hypothesis engine iterates upon breakthrough chemistry from the laboratory to achieve clarity and control over the molecular basis of disease. We focus on the intersection of neuroinflammation and immunology where uncommon molecular insights position us to develop best-in-class therapies for millions of patients in need.",
#         "Batch": "W24",
#         "Company Type": "Active",
#         "Industry Tags": null,
#         "Location": "Location:San Francisco",
#         "Website URL": "https://www.junction.bio/",
#         "Year Founded": "Founded:2024",
#         "Team Size": "Team Size:1",
#         "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680",
#         "Founders": [
#             {
#                 "Name": "Brian Petkov",
#                 "Role": null,
#                 "Biography": "Brian is a theoretical physicist and drug hunter with degrees in mathematics and chemistry from Duke University and doctoral training from NYU. He was previously the first employee and Vice President at a computational drug design startup where he led the Machine Learning operation and grew a 30-person team to success on previously-undruggable targets.",
#                 "LinkedIn Profile": "https://linkedin.com/in/brian-petkov-b2a63680"
#             }
#         ]
#     }
# ]
